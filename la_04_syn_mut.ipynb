# %%
# %run "la_00.ipynb"

# %%
by_nt
# Out:
#                                               nt_genotype     gene  \
# 0                                                   A100C  amacGFP
# 1                           A100C:A201T:G243A:T457A:A489G  amacGFP
# 2                     A100C:A304C:A436C:T452C:T532C:C566T  amacGFP
# 3                                 A100C:A489T:T667C:G681T  amacGFP
# 4                                       A100C:C110G:A598G  amacGFP
# ...                                                   ...      ...
# 118704           T95G:C134T:C170T:C302T:T426C:T621C:A650G  cgreGFP
# 118705  T95G:T116C:C155T:T192C:G403A:C463A:A550G:A628T...  cgreGFP
# 118706                                                 wt  amacGFP
# 118707                                                 wt  cgreGFP
# 118708                                                 wt  ppluGFP
#
#                              aa_genotype_pseudo  total_cell_count  \
# 0                                          E36A            162.69
# ...

# %%
by_nt_upd['replicates_mean_brightness'] = by_nt_upd['replicates_mean_brightness'].apply(np.log10)
by_nt_upd
# Out:
#         Unnamed: 0                                      nt_genotype     gene  \
# 0                0                                            A100C  amacGFP
# 1                1                                A100C:A144T:C172A  amacGFP
# 2                2              A100C:A304C:A436C:T452C:T532C:C566T  amacGFP
# 3                3                                      A100C:A349T  amacGFP
# 4                4                          A100C:A489T:T667C:G681T  amacGFP
# ...            ...                                              ...      ...
# 126561      125673  T661C:C662G:G663C:C664A:A665T:T666G:G667A:A668T  ppluGFP
# 126562      125679                                T666A:G667T:A668G  ppluGFP
# 126563      125682                                            T666C  ppluGFP
# 126564      125686                                            T666G  ppluGFP
# 126565      126565                                               wt  ppluGFP
#
# ...

# %%
by_nt=by_nt_upd

# %% [markdown]
# ## **<font color=purple>Data analysis</font>**

# %% [markdown]
# ### **<font color=blue>General analysis</font>**

# %%
#Take the gene names of the dataset

genes = sorted(set(by_nt.gene))

genes
# Out:
# ['amacGFP', 'cgreGFP', 'ppluGFP']

# %%
#Calculate the brightness of the wildtype genes

wt_brightness = {}
for gene in genes:
    wt = by_nt[(by_nt['gene']== gene) & (by_nt['nt_genotype']=='wt')]
    wt_brightness[gene] = wt['replicates_mean_brightness'].median()
    
wt_brightness
# Out:
# {'amacGFP': 3.9759417642196695,
#  'cgreGFP': 4.494366479589088,
#  'ppluGFP': 4.2269429241006415}

# %%
#Create a new dataset which will be sorted by the amino acid genotype

by_aa = by_nt.groupby(['gene', 'aa_genotype_pseudo']).agg({'nt_genotype': 'all', 
                         'total_cell_count': np.sum, 
                         'n_replicates': np.sum, 
                         'replicates_stdev_weighted': np.median,
                        'ddG_monomer': np.median, 'ddG_monomer_stdev': np.median,
                        'ddG_dimer': np.median, 'ddG_dimer_stdev': np.median})
by_aa.reset_index(inplace=True)

by_aa
# Out:
#           gene aa_genotype_pseudo  nt_genotype  total_cell_count  \
# 0      amacGFP              *246G         True           1986.35
# 1      amacGFP              *246L         True             32.68
# 2      amacGFP              *246R         True            312.67
# 3      amacGFP              *246W         True            331.73
# 4      amacGFP              A160D         True            684.24
# ...        ...                ...          ...               ...
# 92383  ppluGFP         Y95S:N222Y         True             96.47
# 92384  ppluGFP    Y95S:R99C:F113S         True             65.83
# 92385  ppluGFP         Y95S:S192G         True             55.05
# 92386  ppluGFP         Y95S:Y103C         True             88.40
# 92387  ppluGFP                 wt         True        3198404.78
#
#        n_replicates  replicates_stdev_weighted  ddG_monomer  \
# 0             177.0                1311.035247          NaN
# 1               4.0                1122.752059          NaN
# ...

# %%
#Create a new dataset which will be sorted by the amino acid genotype

by_aa = by_nt.groupby(['gene', 'aa_genotype_pseudo']).agg({'nt_genotype': 'all', 
                         'total_cell_count': np.sum, 
                         'n_replicates': np.sum, 
                         'replicates_stdev_weighted': np.median,
                        'ddG_monomer': np.median, 'ddG_monomer_stdev': np.median,
                        'ddG_dimer': np.median, 'ddG_dimer_stdev': np.median})
by_aa.reset_index(inplace=True)

by_aa
# Out:
#           gene aa_genotype_pseudo  nt_genotype  total_cell_count  \
# 0      amacGFP              *246G         True           1986.35
# 1      amacGFP              *246L         True             32.68
# 2      amacGFP              *246R         True            312.67
# 3      amacGFP              *246W         True            331.73
# 4      amacGFP              A160D         True            684.24
# ...        ...                ...          ...               ...
# 92383  ppluGFP         Y95S:N222Y         True             96.47
# 92384  ppluGFP    Y95S:R99C:F113S         True             65.83
# 92385  ppluGFP         Y95S:S192G         True             55.05
# 92386  ppluGFP         Y95S:Y103C         True             88.40
# 92387  ppluGFP                 wt         True        3198404.78
#
#        n_replicates  replicates_stdev_weighted  ddG_monomer  \
# 0             177.0                1311.035247          NaN
# 1               4.0                1122.752059          NaN
# ...

# %% [markdown]
# ### **<font color=blue>Mutation analysis</font>**

# %%
#Calculate the number of single nucleotide mutations and the amino acid mutations and include this values into by_nt

sum_mut = lambda s: (len(s)>0)*(len(s.split(':')))
by_nt['nt_mutnumber'] = by_nt['nt_genotype'].apply(sum_mut)
by_nt['aa_mutnumber'] = by_nt['aa_genotype_pseudo'].apply(sum_mut)

#Calculate the number of synonymous mutations and the nonsynonymous mutations and include this values into by_nt

by_nt['syn_mutnumber'] = by_nt['nt_mutnumber'] - by_nt['aa_mutnumber']
by_nt['nonsyn_mutnumber'] = by_nt['aa_mutnumber']

by_nt
# Out:
#         Unnamed: 0                                      nt_genotype     gene  \
# 0                0                                            A100C  amacGFP
# 1                1                                A100C:A144T:C172A  amacGFP
# 2                2              A100C:A304C:A436C:T452C:T532C:C566T  amacGFP
# 3                3                                      A100C:A349T  amacGFP
# 4                4                          A100C:A489T:T667C:G681T  amacGFP
# ...            ...                                              ...      ...
# 126561      125673  T661C:C662G:G663C:C664A:A665T:T666G:G667A:A668T  ppluGFP
# 126562      125679                                T666A:G667T:A668G  ppluGFP
# 126563      125682                                            T666C  ppluGFP
# 126564      125686                                            T666G  ppluGFP
# 126565      126565                                               wt  ppluGFP
#
# ...

# %% [markdown]
# ## **<font color=purple>Biological questions</font>**

# %% [markdown]
# ### **<font color=blue>1) What is the average of 1, 2, 3, 4, 5 synonymous mutations?</font>**

# %%
#Create a new dataset which will be sorted by gene, amino acid genotype and nucleotide genotype

aa_mut = by_nt.groupby(['gene','aa_genotype_pseudo', 'nt_genotype']).agg({'total_cell_count': np.sum, 
                         'n_replicates': np.sum, 
                         'replicates_stdev_weighted': np.median, 'replicates_mean_brightness': np.mean,
                        'ddG_monomer': np.median, 'ddG_monomer_stdev': np.median,
                        'ddG_dimer': np.median, 'ddG_dimer_stdev': np.median, 'nt_mutnumber': np.mean, 'aa_mutnumber': np.mean,
                                                                 'syn_mutnumber': np.mean,})
aa_mut.reset_index(inplace=True)

aa_mut
# Out:
#            gene aa_genotype_pseudo  nt_genotype  total_cell_count  \
# 0       amacGFP              *246G  A461C:T714G             53.70
# 1       amacGFP              *246G  A461T:T714G            173.12
# 2       amacGFP              *246G  C131A:T714G             39.57
# 3       amacGFP              *246G  C347A:T714G             64.67
# 4       amacGFP              *246G  C579T:T714G             33.31
# ...         ...                ...          ...               ...
# 126561  ppluGFP                 wt        T659A           2550.52
# 126562  ppluGFP                 wt  T659A:C662T            241.75
# 126563  ppluGFP                 wt        T659C           3953.45
# 126564  ppluGFP                 wt        T659G           1991.66
# 126565  ppluGFP                 wt           wt        1742087.97
#
#         n_replicates  replicates_stdev_weighted  replicates_mean_brightness  \
# 0                6.0                 550.913282                    3.966691
# ...

# %% [markdown]
# ## **<font color=green>amacGFP</font>**

# %%
#From the previously created dataset, select the data for the amacGFP gene

aa_mut_amacGFP = aa_mut[aa_mut.gene=='amacGFP']
aa_mut_amacGFP.reset_index(inplace=True)

aa_mut_amacGFP
# Out:
#        index     gene aa_genotype_pseudo  nt_genotype  total_cell_count  \
# 0          0  amacGFP              *246G  A461C:T714G             53.70
# 1          1  amacGFP              *246G  A461T:T714G            173.12
# 2          2  amacGFP              *246G  C131A:T714G             39.57
# 3          3  amacGFP              *246G  C347A:T714G             64.67
# 4          4  amacGFP              *246G  C579T:T714G             33.31
# ...      ...      ...                ...          ...               ...
# 45618  45618  amacGFP                 wt        T689C           1612.56
# 45619  45619  amacGFP                 wt  T689C:C705T             57.37
# 45620  45620  amacGFP                 wt        T689G            203.89
# 45621  45621  amacGFP                 wt  T689G:C710T             71.84
# 45622  45622  amacGFP                 wt           wt         445287.91
#
#        n_replicates  replicates_stdev_weighted  replicates_mean_brightness  \
# ...

# %%
#Calculate the number of different aa genotypes that we have in amacGFP and create a value with all of them

aa_mut_types = aa_mut_amacGFP.aa_genotype_pseudo.unique()

print(len(aa_mut_types))
# Out:
# 34949

# %%
#Loop to do the same as before for just one amino acid genotype but generalised for all

aa_bright_amacGFP = {}
for amino in aa_mut_types:
    aa_bright = aa_mut_amacGFP[aa_mut_amacGFP.aa_genotype_pseudo == amino]
    aa_bright_amacGFP[amino] = aa_bright.groupby('syn_mutnumber', as_index=False)['replicates_mean_brightness'].mean()

aa_bright_amacGFP
# Out:
# {'*246G':    syn_mutnumber  replicates_mean_brightness
#  0              0                    3.972704
#  1              1                    3.990186,
#  '*246L':    syn_mutnumber  replicates_mean_brightness
#  0              0                    3.949572,
#  '*246R':    syn_mutnumber  replicates_mean_brightness
#  0              0                    3.977506
#  1              1                    3.933125,
#  '*246W':    syn_mutnumber  replicates_mean_brightness
#  0              0                    3.989683,
#  'A160D':    syn_mutnumber  replicates_mean_brightness
#  0              0                    3.939211
#  1              1                    3.975733,
#  'A160D:F230L':    syn_mutnumber  replicates_mean_brightness
#  0              1                    3.935258,
#  'A160D:G176R':    syn_mutnumber  replicates_mean_brightness
#  0              1                    3.966105,
#  'A160D:H224N':    syn_mutnumber  replicates_mean_brightness
# ...

# %% [markdown]
# ## **<font color=green>cgreGFP</font>**

# %%
#From the previously created dataset, select the data for the cgreGFP gene

aa_mut_cgreGFP = aa_mut[aa_mut.gene=='cgreGFP']
aa_mut_cgreGFP.reset_index(inplace=True)

aa_mut_cgreGFP
# Out:
#        index     gene aa_genotype_pseudo       nt_genotype  total_cell_count  \
# 0      45623  cgreGFP              *246C             A707T             87.78
# 1      45624  cgreGFP              *246G             T705G           1499.77
# 2      45625  cgreGFP              A113D             C331A            274.17
# 3      45626  cgreGFP        A113D:E229D       C331A:G671T             51.53
# 4      45627  cgreGFP        A113D:E239D       C331A:A695T            232.24
# ...      ...      ...                ...               ...               ...
# 33777  79400  cgreGFP                 wt        T95C:G593A            134.83
# 33778  79401  cgreGFP                 wt        T95C:T242C            155.04
# 33779  79402  cgreGFP                 wt  T95C:T242C:A449T            210.31
# 33780  79403  cgreGFP                 wt  T95C:T542C:A608C            205.55
# 33781  79404  cgreGFP                 wt                wt         733675.46
#
# ...

# %%
#Calculate the number of different aa gennotypes that we have in cgreGFP and create a value with all of them

aa_mut_types_cgre = aa_mut_cgreGFP.aa_genotype_pseudo.unique()

print(len(aa_mut_types_cgre))
# Out:
# 25172

# %%
#Loop to do the same as before for just one amino acid genotype but generalised for all

aa_bright_cgreGFP = {}
for amino in aa_mut_types_cgre:
    aa_bright_cgre = aa_mut_cgreGFP[aa_mut_cgreGFP.aa_genotype_pseudo == amino]
    aa_bright_cgreGFP[amino] = aa_bright_cgre.groupby('syn_mutnumber', as_index=False)['replicates_mean_brightness'].mean()

aa_bright_cgreGFP
# Out:
# {'*246C':    syn_mutnumber  replicates_mean_brightness
#  0              0                    4.302271,
#  '*246G':    syn_mutnumber  replicates_mean_brightness
#  0              0                    4.466539,
#  'A113D':    syn_mutnumber  replicates_mean_brightness
#  0              0                    2.299773,
#  'A113D:E229D':    syn_mutnumber  replicates_mean_brightness
#  0              0                    2.425549,
#  'A113D:E239D':    syn_mutnumber  replicates_mean_brightness
#  0              0                    1.976627,
#  'A113D:H147Q:K165R:A193T':    syn_mutnumber  replicates_mean_brightness
#  0              2                     2.08094,
#  'A113D:K114I:M175K':    syn_mutnumber  replicates_mean_brightness
#  0              0                    2.475661,
#  'A113D:K114R':    syn_mutnumber  replicates_mean_brightness
#  0              0                    2.217319,
#  'A113D:V128L':    syn_mutnumber  replicates_mean_brightness
# ...

# %% [markdown]
# ## **<font color=green>ppluGFP</font>**

# %%
#From the previously created dataset, select the data for the ppluGFP gene

aa_mut_ppluGFP = aa_mut[aa_mut.gene=='ppluGFP']
aa_mut_ppluGFP.reset_index(inplace=True)

aa_mut_ppluGFP
# Out:
#         index     gene aa_genotype_pseudo              nt_genotype  \
# 0       79405  ppluGFP              *246C                    A668T
# 1       79406  ppluGFP              *246C              C443T:A668T
# 2       79407  ppluGFP              *246D  A665T:T666G:G667A:A668T
# 3       79408  ppluGFP              *246G        A131T:C278T:T666G
# 4       79409  ppluGFP              *246G              C188T:T666G
# ...       ...      ...                ...                      ...
# 47156  126561  ppluGFP                 wt                    T659A
# 47157  126562  ppluGFP                 wt              T659A:C662T
# 47158  126563  ppluGFP                 wt                    T659C
# 47159  126564  ppluGFP                 wt                    T659G
# 47160  126565  ppluGFP                 wt                       wt
#
#        total_cell_count  n_replicates  replicates_stdev_weighted  \
# 0                 80.12           5.0                2187.444683
# ...

# %%
#Calculate the number of different aa gennotypes that we have in ppluGFP and create a value with all of them

aa_mut_types_pplu = aa_mut_ppluGFP.aa_genotype_pseudo.unique()

print(len(aa_mut_types_pplu))
# Out:
# 32267

# %%
#Loop to do the same as before for just one amino acid genotype but generalised for all

aa_bright_ppluGFP = {}
for amino in aa_mut_types_pplu:
    aa_bright_pplu = aa_mut_ppluGFP[aa_mut_ppluGFP.aa_genotype_pseudo == amino]
    aa_bright_ppluGFP[amino] = aa_bright_pplu.groupby('syn_mutnumber', as_index=False)['replicates_mean_brightness'].mean()

aa_bright_ppluGFP
# Out:
# {'*246C':    syn_mutnumber  replicates_mean_brightness
#  0              0                    4.219183
#  1              1                    4.221520,
#  '*246D':    syn_mutnumber  replicates_mean_brightness
#  0              3                    4.269007,
#  '*246G':    syn_mutnumber  replicates_mean_brightness
#  0              0                    4.238693
#  1              1                    4.247161
#  2              2                    4.241350
#  3              3                    4.242405,
#  '*246L':    syn_mutnumber  replicates_mean_brightness
#  0              0                    4.251611,
#  '*246M':    syn_mutnumber  replicates_mean_brightness
#  0              2                    4.203663,
#  '*246R':    syn_mutnumber  replicates_mean_brightness
#  0              0                    4.250819
#  1              1                    4.259618,
#  '*246W':    syn_mutnumber  replicates_mean_brightness
#  0              0                    4.187577
# ...

# %% [markdown]
# ## **<font color=green>Global</font>**

# %%
import matplotlib.lines as mlines

zero_marker = mlines.Line2D([], [], color='grey', marker='o',
                          markersize=10, label='0 mutations')
one_marker = mlines.Line2D([], [], color='orange', marker='o',
                          markersize=10, label='1 mutation')
two_marker = mlines.Line2D([], [], color='red', marker='o',
                          markersize=10, label='2 mutations')
three_marker = mlines.Line2D([], [], color='purple', marker='o',
                          markersize=10, label='3 mutations')
four_marker = mlines.Line2D([], [], color='royalblue', marker='o',
                          markersize=10, label='4 mutations')
five_marker = mlines.Line2D([], [], color='green', marker='o',
                          markersize=10, label='5 mutations')

amac_marker = mlines.Line2D([], [], color='lawngreen', marker='o',
                          markersize=10, label='amacGFP')
cgre_marker = mlines.Line2D([], [], color='limegreen', marker='o',
                          markersize=10, label='cgreGFP')
pplu_marker = mlines.Line2D([], [], color='green', marker='o',
                          markersize=10, label='ppluGFP')

# %%
plt.figure(figsize=(50,50))

for gene, dataset, i in [('amacGFP', aa_bright_amacGFP, 1),('cgreGFP', aa_bright_cgreGFP, 2),('ppluGFP', aa_bright_ppluGFP, 3)]:
    plt.subplot(3,1,i)
    plt.ylabel('Mean brightness', size=20)
    plt.xlabel('Amino acid position in the genome', size=20)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.legend(handles=[zero_marker, one_marker, two_marker, three_marker, four_marker, five_marker])
    plt.minorticks_on()
    plt.grid(b=True, which='major', linestyle='-')
    plt.grid(b=True, which='minor', linestyle='--')
    for mutation, series in dataset.items():
        if ':' not in mutation:
            for mutnumber, color in [(0, 'grey'), (1, 'orange'),(2,'red'),(3,'purple'),(4,'royalblue'),(5,'green')]:
                try:
                    position = int(mutation[1:-1])
                    brightness = series[series['syn_mutnumber']==mutnumber]['replicates_mean_brightness'].values[0]
                    plt.plot(position, brightness, marker = 'o', color=color, markersize=10)
                    plt.title(gene, size=30)
                except IndexError:
                    pass
                except ValueError:
                    pass


plt.tight_layout()

plt.savefig('Syn_mut_new.png', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ef97037dd39a> in <module>
#       1 plt.figure(figsize=(50,50))
#       2
# ----> 3 for gene, dataset, i in [('amacGFP', aa_bright_amacGFP, 1),('cgreGFP', aa_bright_cgreGFP, 2),('ppluGFP', aa_bright_ppluGFP, 3)]:
#       4     plt.subplot(3,1,i)
#       5     plt.ylabel('Mean brightness', size=20)
#
# NameError: name 'aa_bright_amacGFP' is not defined

# %%
import seaborn as sns

position = {}
brightness = {}
mutnumber_amacGFP = {}
for mutation,series in aa_bright_amacGFP.items():
    if ':' not in mutation:
        for mutnumber, color in [(0, 'grey'), (1, 'orange'),(2,'red'),(3,'purple'),(4,'royalblue'),(5,'green')]:
            try:
                mutnumber_amacGFP[mutation, mutnumber] = mutnumber
                position[mutation, mutnumber] = int(mutation[1:-1])
                brightness[mutation, mutnumber] = series[series['syn_mutnumber']==mutnumber]['replicates_mean_brightness'].values[0]
            except IndexError:
                pass
            except ValueError:
                pass
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-9caa2e44c49c> in <module>
# ----> 1 import seaborn as sns
#       2
#       3 position = {}
#       4 brightness = {}
#       5 mutnumber_amacGFP = {}
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pos_amacGFP = pd.DataFrame.from_dict(position, orient='index')
bri_amacGFP = pd.DataFrame.from_dict(brightness, orient='index')
mutnum_amacGFP = pd.DataFrame.from_dict(mutnumber_amacGFP, orient='index')
result_amacGFP = pd.concat([pos_amacGFP, bri_amacGFP, mutnum_amacGFP], axis=1, sort=False)
result_amacGFP = result_amacGFP.dropna()
result_amacGFP.columns =['Position', 'Brightness', 'Mutation number']
result_amacGFP

# %%
#plt.figure(figsize=(50,20))
#sns.boxplot(x='Position', y='Brightness', data=result_amacGFP, hue='Mutation number', palette=['grey', 'orange', 'red', 'purple','royalblue','green'])
#plt.ylabel('Mean brightness', size=20)
#plt.xlabel('Amino acid position in the genome', size=20)
#plt.tight_layout()

# %%
position = {}
brightness = {}
mutnumber_cgreGFP = {}
for mutation,series in aa_bright_cgreGFP.items():
    if ':' not in mutation:
        for mutnumber, color in [(0, 'grey'), (1, 'orange'),(2,'red'),(3,'purple'),(4,'royalblue'),(5,'green')]:
            try:
                mutnumber_cgreGFP[mutation, mutnumber] = mutnumber
                position[mutation, mutnumber] = int(mutation[1:-1])
                brightness[mutation, mutnumber] = series[series['syn_mutnumber']==mutnumber]['replicates_mean_brightness'].values[0]
            except IndexError:
                pass
            except ValueError:
                pass

# %%
pos_cgreGFP = pd.DataFrame.from_dict(position, orient='index')
bri_cgreGFP = pd.DataFrame.from_dict(brightness, orient='index')
mutnum_cgreGFP = pd.DataFrame.from_dict(mutnumber_cgreGFP, orient='index')
result_cgreGFP = pd.concat([pos_cgreGFP, bri_cgreGFP, mutnum_cgreGFP], axis=1, sort=False)
result_cgreGFP = result_cgreGFP.dropna()
result_cgreGFP.columns =['Position', 'Brightness', 'Mutation number']
result_cgreGFP

# %%
#plt.figure(figsize=(50,20))
#sns.boxplot(x='Position', y='Brightness', data=result_cgreGFP, hue='Mutation number', palette=['grey', 'orange', 'red', 'purple','royalblue','green'])
#plt.ylabel('Mean brightness', size=20)
#plt.xlabel('Amino acid position in the genome', size=20)
#plt.tight_layout()

# %%
position = {}
brightness = {}
mutnumber_ppluGFP = {}
for mutation,series in aa_bright_ppluGFP.items():
    if ':' not in mutation:
        for mutnumber, color in [(0, 'grey'), (1, 'orange'),(2,'red'),(3,'purple'),(4,'royalblue'),(5,'green')]:
            try:
                mutnumber_ppluGFP[mutation, mutnumber] = mutnumber
                position[mutation, mutnumber] = int(mutation[1:-1])
                brightness[mutation, mutnumber] = series[series['syn_mutnumber']==mutnumber]['replicates_mean_brightness'].values[0]
            except IndexError:
                pass
            except ValueError:
                pass

# %%
pos_ppluGFP = pd.DataFrame.from_dict(position, orient='index')
bri_ppluGFP = pd.DataFrame.from_dict(brightness, orient='index')
mutnum_ppluGFP = pd.DataFrame.from_dict(mutnumber_ppluGFP, orient='index')
result_ppluGFP = pd.concat([pos_ppluGFP, bri_ppluGFP, mutnum_ppluGFP], axis=1, sort=False)
result_ppluGFP = result_ppluGFP.dropna()
result_ppluGFP.columns =['Position', 'Brightness', 'Mutation number']
result_ppluGFP

# %%
#plt.figure(figsize=(50,20))
#sns.boxplot(x='Position', y='Brightness', data=result_ppluGFP, hue='Mutation number', palette=['grey', 'orange', 'red', 'purple','royalblue','green'])
#plt.ylabel('Mean brightness', size=20)
#plt.xlabel('Amino acid position in the genome', size=20)
#plt.tight_layout()

# %% [markdown]
# ## **<font color=green>Global</font>**

# %%
plt.figure(figsize=(50,50))
for gene, dataset, i in [('amacGFP', result_amacGFP, 1),('cgreGFP', result_cgreGFP, 2),('ppluGFP', result_ppluGFP, 3)]:
    plt.subplot(3,1,i)
    ax=sns.boxplot(x='Position', y='Brightness', data=dataset, hue='Mutation number', 
                palette=['grey','orange', 'red', 'purple','royalblue','green'])
    ax.set_xlabel('Amino acid position in the genome')
    ax.set_ylabel('Mean brightness')
    #ax.set_xticks(np.arange(0, 250, 5))
    plt.title(gene, size=30)

plt.tight_layout()
plt.savefig('Syn_mut_box_new.png', dpi=300)

# %% [markdown]
#  ### **<font color=blue>2) Average effect of synonymous mutations at a codon vs average amino acid substitution at this position?</font>**

# %% [markdown]
# ### **<font color=orange>Mean</font>**

# %% [markdown]
# ## **<font color=green>amacGFP</font>**

# %%
aa_pos_amacGFP = result_amacGFP.Position.unique()

print(len(aa_pos_amacGFP))

# %%
aa_average_amacGFP = {}
for pos in aa_pos_amacGFP:
    aa_average_amac = result_amacGFP[result_amacGFP.Position == pos]
    aa_average_amacGFP[pos] = aa_average_amac['Brightness'].mean()

aa_average0_amacGFP = {}
for pos in aa_pos_amacGFP:
    aa_average0_amac = result_amacGFP[result_amacGFP.Position == pos]
    aa_average0_amacGFP[pos] = aa_average0_amac[aa_average0_amac['Mutation number']==0]['Brightness'].mean()

aa_average1_amacGFP = {}
for pos in aa_pos_amacGFP:
    aa_average1_amac = result_amacGFP[result_amacGFP.Position == pos]
    aa_average1_amacGFP[pos] = aa_average1_amac[aa_average1_amac['Mutation number']==1]['Brightness'].mean()

aa_average2_amacGFP = {}
for pos in aa_pos_amacGFP:
    aa_average2_amac = result_amacGFP[result_amacGFP.Position == pos]
    aa_average2_amacGFP[pos] = aa_average2_amac[aa_average2_amac['Mutation number']==2]['Brightness'].mean()

aa_average3_amacGFP = {}
for pos in aa_pos_amacGFP:
    aa_average3_amac = result_amacGFP[result_amacGFP.Position == pos]
    aa_average3_amacGFP[pos] = aa_average3_amac[aa_average3_amac['Mutation number']==3]['Brightness'].mean()

aa_average4_amacGFP = {}
for pos in aa_pos_amacGFP:
    aa_average4_amac = result_amacGFP[result_amacGFP.Position == pos]
    aa_average4_amacGFP[pos] = aa_average4_amac[aa_average4_amac['Mutation number']==4]['Brightness'].mean()

aa_average5_amacGFP = {}
for pos in aa_pos_amacGFP:
    aa_average5_amac = result_amacGFP[result_amacGFP.Position == pos]
    aa_average5_amacGFP[pos] = aa_average5_amac[aa_average5_amac['Mutation number']==5]['Brightness'].mean()

# %%
aa_average_amacGFP = pd.DataFrame.from_dict(aa_average_amacGFP, orient='index')
aa_average0_amacGFP = pd.DataFrame.from_dict(aa_average0_amacGFP, orient='index')
aa_average1_amacGFP = pd.DataFrame.from_dict(aa_average1_amacGFP, orient='index')
aa_average2_amacGFP = pd.DataFrame.from_dict(aa_average2_amacGFP, orient='index')
aa_average3_amacGFP = pd.DataFrame.from_dict(aa_average3_amacGFP, orient='index')
aa_average4_amacGFP = pd.DataFrame.from_dict(aa_average4_amacGFP, orient='index')
aa_average5_amacGFP = pd.DataFrame.from_dict(aa_average5_amacGFP, orient='index')
result_average_amacGFP = pd.concat([aa_average_amacGFP, aa_average0_amacGFP, aa_average1_amacGFP, aa_average2_amacGFP, aa_average3_amacGFP, aa_average4_amacGFP, aa_average5_amacGFP], axis=1, sort=False)
result_average_amacGFP.columns =['Average', '0 Mutations', '1 Mutation', '2 Mutations', '3 Mutations', '4 Mutations', '5 Mutations']
result_average_amacGFP = result_average_amacGFP.rename_axis('Position').reset_index()
result_average_amacGFP

# %%
plt.figure(figsize=(50,50))

ax = result_average_amacGFP.plot(kind='scatter', x='Position', y='Average', color='black', label='Average', s=10)
result_average_amacGFP.plot(kind='scatter', x='Position', y='0 Mutations', color='grey', label='0 Mutations', s=10, ax=ax)  
result_average_amacGFP.plot(kind='scatter', x='Position', y='1 Mutation', color='orange', label='1 Mutation', s=10, ax=ax)  
result_average_amacGFP.plot(kind='scatter', x='Position', y='2 Mutations', color='red', label='2 Mutations', s=10, ax=ax)  
result_average_amacGFP.plot(kind='scatter', x='Position', y='3 Mutations', color='purple', label='3 Mutations', s=10, ax=ax)  
result_average_amacGFP.plot(kind='scatter', x='Position', y='4 Mutations', color='royalblue', label='4 Mutations', s=10, ax=ax)
result_average_amacGFP.plot(kind='scatter', x='Position', y='5 Mutations', color='green', label='5 Mutations', s=10, ax=ax)  
ax.set_xlabel("Amino acid position in the genome")
ax.set_ylabel("Mean brightness")

plt.tight_layout()

#plt.savefig('Syn_mut_amac_average.png', dpi=300)

# %%
plt.figure(figsize=(50,50))

 
ax = result_average_amacGFP.plot(kind='scatter', x='Average', y='0 Mutations', color='grey', label='0 Mutations', s=10)
result_average_amacGFP.plot(kind='scatter', x='Average', y='1 Mutation', color='orange', label='1 Mutation', s=10, ax=ax)
result_average_amacGFP.plot(kind='scatter', x='Average', y='2 Mutations', color='red', label='2 Mutations', s=10, ax=ax)  
result_average_amacGFP.plot(kind='scatter', x='Average', y='3 Mutations', color='purple', label='3 Mutations', s=10, ax=ax)  
result_average_amacGFP.plot(kind='scatter', x='Average', y='4 Mutations', color='royalblue', label='4 Mutations', s=10, ax=ax)
result_average_amacGFP.plot(kind='scatter', x='Average', y='5 Mutations', color='green', label='5 Mutations', s=10, ax=ax)  
ax.set_xlabel("Average brightness codon")
ax.set_ylabel("Average brightness mutations")

plt.tight_layout()

plt.savefig('Syn_mut_amac_average_bis_new.png', dpi=300)

# %% [markdown]
# ## **<font color=green>cgreGFP</font>**

# %%
aa_pos_cgreGFP = result_cgreGFP.Position.unique()

print(len(aa_pos_cgreGFP))

# %%
aa_average_cgreGFP = {}
for pos in aa_pos_cgreGFP:
    aa_average_cgre = result_cgreGFP[result_cgreGFP.Position == pos]
    aa_average_cgreGFP[pos] = aa_average_cgre['Brightness'].mean()

aa_average0_cgreGFP = {}
for pos in aa_pos_cgreGFP:
    aa_average0_cgre = result_cgreGFP[result_cgreGFP.Position == pos]
    aa_average0_cgreGFP[pos] = aa_average0_cgre[aa_average0_cgre['Mutation number']==0]['Brightness'].mean()
    
aa_average1_cgreGFP = {}
for pos in aa_pos_cgreGFP:
    aa_average1_cgre = result_cgreGFP[result_cgreGFP.Position == pos]
    aa_average1_cgreGFP[pos] = aa_average1_cgre[aa_average1_cgre['Mutation number']==1]['Brightness'].mean()
    
aa_average2_cgreGFP = {}
for pos in aa_pos_cgreGFP:
    aa_average2_cgre = result_cgreGFP[result_cgreGFP.Position == pos]
    aa_average2_cgreGFP[pos] = aa_average2_cgre[aa_average2_cgre['Mutation number']==2]['Brightness'].mean()
    
aa_average3_cgreGFP = {}
for pos in aa_pos_cgreGFP:
    aa_average3_cgre = result_cgreGFP[result_cgreGFP.Position == pos]
    aa_average3_cgreGFP[pos] = aa_average3_cgre[aa_average3_cgre['Mutation number']==3]['Brightness'].mean()
    
aa_average4_cgreGFP = {}
for pos in aa_pos_cgreGFP:
    aa_average4_cgre = result_cgreGFP[result_cgreGFP.Position == pos]
    aa_average4_cgreGFP[pos] = aa_average4_cgre[aa_average4_cgre['Mutation number']==4]['Brightness'].mean()
    
aa_average5_cgreGFP = {}
for pos in aa_pos_cgreGFP:
    aa_average5_cgre = result_cgreGFP[result_cgreGFP.Position == pos]
    aa_average5_cgreGFP[pos] = aa_average5_cgre[aa_average5_cgre['Mutation number']==5]['Brightness'].mean()

# %%
aa_average_cgreGFP = pd.DataFrame.from_dict(aa_average_cgreGFP, orient='index')
aa_average0_cgreGFP = pd.DataFrame.from_dict(aa_average0_cgreGFP, orient='index')
aa_average1_cgreGFP = pd.DataFrame.from_dict(aa_average1_cgreGFP, orient='index')
aa_average2_cgreGFP = pd.DataFrame.from_dict(aa_average2_cgreGFP, orient='index')
aa_average3_cgreGFP = pd.DataFrame.from_dict(aa_average3_cgreGFP, orient='index')
aa_average4_cgreGFP = pd.DataFrame.from_dict(aa_average4_cgreGFP, orient='index')
aa_average5_cgreGFP = pd.DataFrame.from_dict(aa_average5_cgreGFP, orient='index')

result_average_cgreGFP = pd.concat([aa_average_cgreGFP, aa_average0_cgreGFP, aa_average1_cgreGFP, aa_average2_cgreGFP, aa_average3_cgreGFP, aa_average4_cgreGFP, aa_average5_cgreGFP], axis=1, sort=False)
result_average_cgreGFP.columns =['Average','0 Mutations', '1 Mutation', '2 Mutations', '3 Mutations', '4 Mutations', '5 Mutations']
result_average_cgreGFP = result_average_cgreGFP.rename_axis('Position').reset_index()

result_average_cgreGFP

# %%
plt.figure(figsize=(50,50))

ax1 = result_average_cgreGFP.plot(kind='scatter', x='Position', y='Average', color='black', label='Average', s=10)    
result_average_cgreGFP.plot(kind='scatter', x='Position', y='0 Mutations', color='grey', label='0 Mutations', s=10, ax=ax1)
result_average_cgreGFP.plot(kind='scatter', x='Position', y='1 Mutation', color='orange', label='1 Mutation', s=10, ax=ax1)  
result_average_cgreGFP.plot(kind='scatter', x='Position', y='2 Mutations', color='red', label='2 Mutations', s=10, ax=ax1)  
result_average_cgreGFP.plot(kind='scatter', x='Position', y='3 Mutations', color='purple', label='3 Mutations', s=10, ax=ax1)  
result_average_cgreGFP.plot(kind='scatter', x='Position', y='4 Mutations', color='royalblue', label='4 Mutations', s=10, ax=ax1)
result_average_cgreGFP.plot(kind='scatter', x='Position', y='5 Mutations', color='green', label='5 Mutations', s=10, ax=ax1)  
ax1.set_xlabel("Amino acid position in the genome")
ax1.set_ylabel("Mean brightness")

plt.tight_layout()

#plt.savefig('Syn_mut_cgre_average.png', dpi=300)

# %%
plt.figure(figsize=(50,50))

 
ax1 = result_average_cgreGFP.plot(kind='scatter', x='Average', y='0 Mutations', color='grey', label='0 Mutations', s=10)
result_average_cgreGFP.plot(kind='scatter', x='Average', y='1 Mutation', color='orange', label='1 Mutation', s=10, ax=ax1)
result_average_cgreGFP.plot(kind='scatter', x='Average', y='2 Mutations', color='red', label='2 Mutations', s=10, ax=ax1)  
result_average_cgreGFP.plot(kind='scatter', x='Average', y='3 Mutations', color='purple', label='3 Mutations', s=10, ax=ax1)  
result_average_cgreGFP.plot(kind='scatter', x='Average', y='4 Mutations', color='royalblue', label='4 Mutations', s=10, ax=ax1)
result_average_cgreGFP.plot(kind='scatter', x='Average', y='5 Mutations', color='green', label='5 Mutations', s=10, ax=ax1)  
ax1.set_xlabel("Average brightness codon")
ax1.set_ylabel("Average brightness mutations")

plt.tight_layout()

plt.savefig('Syn_mut_cgre_average_bis_new.png', dpi=300)

# %% [markdown]
# ## **<font color=green>ppluGFP</font>**

# %%
aa_pos_ppluGFP = result_ppluGFP.Position.unique()

print(len(aa_pos_ppluGFP))

# %%
aa_average_ppluGFP = {}
for pos in aa_pos_ppluGFP:
    aa_average_pplu = result_ppluGFP[result_ppluGFP.Position == pos]
    aa_average_ppluGFP[pos] = aa_average_pplu['Brightness'].mean()

aa_average0_ppluGFP = {}
for pos in aa_pos_ppluGFP:
    aa_average0_pplu = result_ppluGFP[result_ppluGFP.Position == pos]
    aa_average0_ppluGFP[pos] = aa_average0_pplu[aa_average0_pplu['Mutation number']==0]['Brightness'].mean()
    
aa_average1_ppluGFP = {}
for pos in aa_pos_ppluGFP:
    aa_average1_pplu = result_ppluGFP[result_ppluGFP.Position == pos]
    aa_average1_ppluGFP[pos] = aa_average1_pplu[aa_average1_pplu['Mutation number']==1]['Brightness'].mean()
    
aa_average2_ppluGFP = {}
for pos in aa_pos_ppluGFP:
    aa_average2_pplu = result_ppluGFP[result_ppluGFP.Position == pos]
    aa_average2_ppluGFP[pos] = aa_average2_pplu[aa_average2_pplu['Mutation number']==2]['Brightness'].mean()
    
aa_average3_ppluGFP = {}
for pos in aa_pos_ppluGFP:
    aa_average3_pplu = result_ppluGFP[result_ppluGFP.Position == pos]
    aa_average3_ppluGFP[pos] = aa_average3_pplu[aa_average3_pplu['Mutation number']==3]['Brightness'].mean()
    
aa_average4_ppluGFP = {}
for pos in aa_pos_ppluGFP:
    aa_average4_pplu = result_ppluGFP[result_ppluGFP.Position == pos]
    aa_average4_ppluGFP[pos] = aa_average4_pplu[aa_average4_pplu['Mutation number']==4]['Brightness'].mean()
    
aa_average5_ppluGFP = {}
for pos in aa_pos_ppluGFP:
    aa_average5_pplu = result_ppluGFP[result_ppluGFP.Position == pos]
    aa_average5_ppluGFP[pos] = aa_average5_pplu[aa_average5_pplu['Mutation number']==5]['Brightness'].mean()

# %%
aa_average_ppluGFP = pd.DataFrame.from_dict(aa_average_ppluGFP, orient='index')
aa_average0_ppluGFP = pd.DataFrame.from_dict(aa_average0_ppluGFP, orient='index')
aa_average1_ppluGFP = pd.DataFrame.from_dict(aa_average1_ppluGFP, orient='index')
aa_average2_ppluGFP = pd.DataFrame.from_dict(aa_average2_ppluGFP, orient='index')
aa_average3_ppluGFP = pd.DataFrame.from_dict(aa_average3_ppluGFP, orient='index')
aa_average4_ppluGFP = pd.DataFrame.from_dict(aa_average4_ppluGFP, orient='index')
aa_average5_ppluGFP = pd.DataFrame.from_dict(aa_average5_ppluGFP, orient='index')

result_average_ppluGFP = pd.concat([aa_average_ppluGFP, aa_average0_ppluGFP, aa_average1_ppluGFP, aa_average2_ppluGFP, aa_average3_ppluGFP, aa_average4_ppluGFP, aa_average5_ppluGFP], axis=1, sort=False)
result_average_ppluGFP.columns =['Average', '0 Mutations', '1 Mutation', '2 Mutations', '3 Mutations', '4 Mutations', '5 Mutations']
result_average_ppluGFP = result_average_ppluGFP.rename_axis('Position').reset_index()

result_average_ppluGFP

# %%
plt.figure(figsize=(50,50))

ax2 = result_average_ppluGFP.plot(kind='scatter', x='Position', y='Average', color='black', label='Average', s=10)
result_average_ppluGFP.plot(kind='scatter', x='Position', y='0 Mutations', color='grey', label='0 Mutations', s=10, ax=ax2) 
result_average_ppluGFP.plot(kind='scatter', x='Position', y='1 Mutation', color='orange', label='1 Mutation', s=10, ax=ax2)  
result_average_ppluGFP.plot(kind='scatter', x='Position', y='2 Mutations', color='red', label='2 Mutations', s=10, ax=ax2)  
result_average_ppluGFP.plot(kind='scatter', x='Position', y='3 Mutations', color='purple', label='3 Mutations', s=10, ax=ax2)  
result_average_ppluGFP.plot(kind='scatter', x='Position', y='4 Mutations', color='royalblue', label='4 Mutations', s=10, ax=ax2)
result_average_ppluGFP.plot(kind='scatter', x='Position', y='5 Mutations', color='green', label='5 Mutations', s=10, ax=ax2)  
ax2.set_xlabel("Amino acid position in the genome")
ax2.set_ylabel("Mean brightness")

plt.tight_layout()

#plt.savefig('Syn_mut_pplu_average.png', dpi=300)

# %%
plt.figure(figsize=(50,50))

 
ax2 = result_average_ppluGFP.plot(kind='scatter', x='Average', y='0 Mutations', color='grey', label='0 Mutations', s=10)
result_average_ppluGFP.plot(kind='scatter', x='Average', y='1 Mutation', color='orange', label='1 Mutation', s=10, ax=ax2) 
result_average_ppluGFP.plot(kind='scatter', x='Average', y='2 Mutations', color='red', label='2 Mutations', s=10, ax=ax2)  
result_average_ppluGFP.plot(kind='scatter', x='Average', y='3 Mutations', color='purple', label='3 Mutations', s=10, ax=ax2)  
result_average_ppluGFP.plot(kind='scatter', x='Average', y='4 Mutations', color='royalblue', label='4 Mutations', s=10, ax=ax2)
result_average_ppluGFP.plot(kind='scatter', x='Average', y='5 Mutations', color='green', label='5 Mutations', s=10, ax=ax2)  
ax2.set_xlabel("Average brightness codon")
ax2.set_ylabel("Average brightness mutations")

plt.tight_layout()

plt.savefig('Syn_mut_pplu_average_bis_new.png', dpi=300)

# %% [markdown]
# ## **<font color=green>Global</font>**

# %%
figure, axes = plt.subplots(3,1, figsize=(20,30))

result_average_amacGFP.plot(kind='scatter', x='Average', y='0 Mutations', color='grey', label='0 Mutations', s=10, alpha=0.5, ax=axes[0])
result_average_amacGFP.plot(kind='scatter', x='Average', y='1 Mutation', color='orange', label='1 Mutation', s=10, alpha=0.5, ax=axes[0])
result_average_amacGFP.plot(kind='scatter', x='Average', y='2 Mutations', color='red', label='2 Mutations', s=10, alpha=0.5, ax=axes[0])  
result_average_amacGFP.plot(kind='scatter', x='Average', y='3 Mutations', color='purple', label='3 Mutations', s=10, alpha=0.5, ax=axes[0])  
result_average_amacGFP.plot(kind='scatter', x='Average', y='4 Mutations', color='royalblue', label='4 Mutations', s=10, alpha=0.5, ax=axes[0])
result_average_amacGFP.plot(kind='scatter', x='Average', y='5 Mutations', color='green', label='5 Mutations', s=10, alpha=0.5, ax=axes[0])  
axes[0].set_title('amacGFP')


result_average_cgreGFP.plot(kind='scatter', x='Average', y='0 Mutations', color='grey', label='0 Mutations', s=10, alpha=0.5, ax=axes[1])
result_average_cgreGFP.plot(kind='scatter', x='Average', y='1 Mutation', color='orange', label='1 Mutation', s=10, alpha=0.5, ax=axes[1])
result_average_cgreGFP.plot(kind='scatter', x='Average', y='2 Mutations', color='red', label='2 Mutations', s=10, alpha=0.5, ax=axes[1])  
result_average_cgreGFP.plot(kind='scatter', x='Average', y='3 Mutations', color='purple', label='3 Mutations', s=10, alpha=0.5, ax=axes[1])  
result_average_cgreGFP.plot(kind='scatter', x='Average', y='4 Mutations', color='royalblue', label='4 Mutations', s=10, alpha=0.5, ax=axes[1])
result_average_cgreGFP.plot(kind='scatter', x='Average', y='5 Mutations', color='green', label='5 Mutations', s=10, alpha=0.5, ax=axes[1])  
axes[1].set_title('cgreGFP')


result_average_ppluGFP.plot(kind='scatter', x='Average', y='0 Mutations', color='grey', label='0 Mutations', s=10, alpha=0.5, ax=axes[2])
result_average_ppluGFP.plot(kind='scatter', x='Average', y='1 Mutation', color='orange', label='1 Mutation', s=10, alpha=0.5, ax=axes[2]) 
result_average_ppluGFP.plot(kind='scatter', x='Average', y='2 Mutations', color='red', label='2 Mutations', s=10, alpha=0.5, ax=axes[2])  
result_average_ppluGFP.plot(kind='scatter', x='Average', y='3 Mutations', color='purple', label='3 Mutations', s=10, alpha=0.5, ax=axes[2])  
result_average_ppluGFP.plot(kind='scatter', x='Average', y='4 Mutations', color='royalblue', label='4 Mutations', s=10, alpha=0.5, ax=axes[2])
result_average_ppluGFP.plot(kind='scatter', x='Average', y='5 Mutations', color='green', label='5 Mutations', s=10, alpha=0.5, ax=axes[2])  
axes[2].set_title('ppluGFP')

for ax in axes.flat:
    ax.set(xlabel='Average brightness codon', ylabel='Average brightness codon')

plt.savefig('Syn_mut_global_average_new.png', dpi=300)

# %% [markdown]
# ### **<font color=orange>Median</font>**

# %% [markdown]
# ## **<font color=green>amacGFP</font>**

# %%
aa_median_amacGFP = {}
for pos in aa_pos_amacGFP:
    aa_median_amac = result_amacGFP[result_amacGFP.Position == pos]
    aa_median_amacGFP[pos] = aa_median_amac['Brightness'].median()

aa_median0_amacGFP = {}
for pos in aa_pos_amacGFP:
    aa_median0_amac = result_amacGFP[result_amacGFP.Position == pos]
    aa_median0_amacGFP[pos] = aa_median0_amac[aa_median0_amac['Mutation number']==0]['Brightness'].median()

aa_median1_amacGFP = {}
for pos in aa_pos_amacGFP:
    aa_median1_amac = result_amacGFP[result_amacGFP.Position == pos]
    aa_median1_amacGFP[pos] = aa_median1_amac[aa_median1_amac['Mutation number']==1]['Brightness'].median()

aa_median2_amacGFP = {}
for pos in aa_pos_amacGFP:
    aa_median2_amac = result_amacGFP[result_amacGFP.Position == pos]
    aa_median2_amacGFP[pos] = aa_median2_amac[aa_median2_amac['Mutation number']==2]['Brightness'].median()

aa_median3_amacGFP = {}
for pos in aa_pos_amacGFP:
    aa_median3_amac = result_amacGFP[result_amacGFP.Position == pos]
    aa_median3_amacGFP[pos] = aa_median3_amac[aa_median3_amac['Mutation number']==3]['Brightness'].median()

aa_median4_amacGFP = {}
for pos in aa_pos_amacGFP:
    aa_median4_amac = result_amacGFP[result_amacGFP.Position == pos]
    aa_median4_amacGFP[pos] = aa_median4_amac[aa_median4_amac['Mutation number']==4]['Brightness'].median()

aa_median5_amacGFP = {}
for pos in aa_pos_amacGFP:
    aa_median5_amac = result_amacGFP[result_amacGFP.Position == pos]
    aa_median5_amacGFP[pos] = aa_median5_amac[aa_median5_amac['Mutation number']==5]['Brightness'].median()

# %%
aa_median_amacGFP = pd.DataFrame.from_dict(aa_median_amacGFP, orient='index')
aa_median0_amacGFP = pd.DataFrame.from_dict(aa_median0_amacGFP, orient='index')
aa_median1_amacGFP = pd.DataFrame.from_dict(aa_median1_amacGFP, orient='index')
aa_median2_amacGFP = pd.DataFrame.from_dict(aa_median2_amacGFP, orient='index')
aa_median3_amacGFP = pd.DataFrame.from_dict(aa_median3_amacGFP, orient='index')
aa_median4_amacGFP = pd.DataFrame.from_dict(aa_median4_amacGFP, orient='index')
aa_median5_amacGFP = pd.DataFrame.from_dict(aa_median5_amacGFP, orient='index')

result_median_amacGFP = pd.concat([aa_median_amacGFP, aa_median0_amacGFP, aa_median1_amacGFP, aa_median2_amacGFP, aa_median3_amacGFP, aa_median4_amacGFP, aa_median5_amacGFP], axis=1, sort=False)
result_median_amacGFP.columns =['Median', '0 Mutations', '1 Mutation', '2 Mutations', '3 Mutations', '4 Mutations', '5 Mutations']
result_median_amacGFP = result_median_amacGFP.rename_axis('Position').reset_index()

result_median_amacGFP

# %% [markdown]
# ## **<font color=green>cgreGFP</font>**

# %%
aa_median_cgreGFP = {}
for pos in aa_pos_cgreGFP:
    aa_median_cgre = result_cgreGFP[result_cgreGFP.Position == pos]
    aa_median_cgreGFP[pos] = aa_median_cgre['Brightness'].median()

aa_median0_cgreGFP = {}
for pos in aa_pos_cgreGFP:
    aa_median0_cgre = result_cgreGFP[result_cgreGFP.Position == pos]
    aa_median0_cgreGFP[pos] = aa_median0_cgre[aa_median0_cgre['Mutation number']==0]['Brightness'].median()
    
aa_median1_cgreGFP = {}
for pos in aa_pos_cgreGFP:
    aa_median1_cgre = result_cgreGFP[result_cgreGFP.Position == pos]
    aa_median1_cgreGFP[pos] = aa_median1_cgre[aa_median1_cgre['Mutation number']==1]['Brightness'].median()
    
aa_median2_cgreGFP = {}
for pos in aa_pos_cgreGFP:
    aa_median2_cgre = result_cgreGFP[result_cgreGFP.Position == pos]
    aa_median2_cgreGFP[pos] = aa_median2_cgre[aa_median2_cgre['Mutation number']==2]['Brightness'].median()
    
aa_median3_cgreGFP = {}
for pos in aa_pos_cgreGFP:
    aa_median3_cgre = result_cgreGFP[result_cgreGFP.Position == pos]
    aa_median3_cgreGFP[pos] = aa_median3_cgre[aa_median3_cgre['Mutation number']==3]['Brightness'].median()
    
aa_median4_cgreGFP = {}
for pos in aa_pos_cgreGFP:
    aa_median4_cgre = result_cgreGFP[result_cgreGFP.Position == pos]
    aa_median4_cgreGFP[pos] = aa_median4_cgre[aa_median4_cgre['Mutation number']==4]['Brightness'].median()
    
aa_median5_cgreGFP = {}
for pos in aa_pos_cgreGFP:
    aa_median5_cgre = result_cgreGFP[result_cgreGFP.Position == pos]
    aa_median5_cgreGFP[pos] = aa_median5_cgre[aa_median5_cgre['Mutation number']==5]['Brightness'].median()

# %%
aa_median_cgreGFP = pd.DataFrame.from_dict(aa_median_cgreGFP, orient='index')
aa_median0_cgreGFP = pd.DataFrame.from_dict(aa_median0_cgreGFP, orient='index')
aa_median1_cgreGFP = pd.DataFrame.from_dict(aa_median1_cgreGFP, orient='index')
aa_median2_cgreGFP = pd.DataFrame.from_dict(aa_median2_cgreGFP, orient='index')
aa_median3_cgreGFP = pd.DataFrame.from_dict(aa_median3_cgreGFP, orient='index')
aa_median4_cgreGFP = pd.DataFrame.from_dict(aa_median4_cgreGFP, orient='index')
aa_median5_cgreGFP = pd.DataFrame.from_dict(aa_median5_cgreGFP, orient='index')

result_median_cgreGFP = pd.concat([aa_median_cgreGFP, aa_median0_cgreGFP, aa_median1_cgreGFP, aa_median2_cgreGFP, aa_median3_cgreGFP, aa_median4_cgreGFP, aa_median5_cgreGFP], axis=1, sort=False)
result_median_cgreGFP.columns =['Median','0 Mutations', '1 Mutation', '2 Mutations', '3 Mutations', '4 Mutations', '5 Mutations']
result_median_cgreGFP = result_median_cgreGFP.rename_axis('Position').reset_index()

result_median_cgreGFP

# %% [markdown]
# ## **<font color=green>ppluGFP</font>**

# %%
aa_median_ppluGFP = {}
for pos in aa_pos_ppluGFP:
    aa_median_pplu = result_ppluGFP[result_ppluGFP.Position == pos]
    aa_median_ppluGFP[pos] = aa_median_pplu['Brightness'].median()

aa_median0_ppluGFP = {}
for pos in aa_pos_ppluGFP:
    aa_median0_pplu = result_ppluGFP[result_ppluGFP.Position == pos]
    aa_median0_ppluGFP[pos] = aa_median0_pplu[aa_median0_pplu['Mutation number']==0]['Brightness'].median()
    
aa_median1_ppluGFP = {}
for pos in aa_pos_ppluGFP:
    aa_median1_pplu = result_ppluGFP[result_ppluGFP.Position == pos]
    aa_median1_ppluGFP[pos] = aa_median1_pplu[aa_median1_pplu['Mutation number']==1]['Brightness'].median()
    
aa_median2_ppluGFP = {}
for pos in aa_pos_ppluGFP:
    aa_median2_pplu = result_ppluGFP[result_ppluGFP.Position == pos]
    aa_median2_ppluGFP[pos] = aa_median2_pplu[aa_median2_pplu['Mutation number']==2]['Brightness'].median()
    
aa_median3_ppluGFP = {}
for pos in aa_pos_ppluGFP:
    aa_median3_pplu = result_ppluGFP[result_ppluGFP.Position == pos]
    aa_median3_ppluGFP[pos] = aa_median3_pplu[aa_median3_pplu['Mutation number']==3]['Brightness'].median()
    
aa_median4_ppluGFP = {}
for pos in aa_pos_ppluGFP:
    aa_median4_pplu = result_ppluGFP[result_ppluGFP.Position == pos]
    aa_median4_ppluGFP[pos] = aa_median4_pplu[aa_median4_pplu['Mutation number']==4]['Brightness'].median()
    
aa_median5_ppluGFP = {}
for pos in aa_pos_ppluGFP:
    aa_median5_pplu = result_ppluGFP[result_ppluGFP.Position == pos]
    aa_median5_ppluGFP[pos] = aa_median5_pplu[aa_median5_pplu['Mutation number']==5]['Brightness'].median()

# %%
aa_median_ppluGFP = pd.DataFrame.from_dict(aa_median_ppluGFP, orient='index')
aa_median0_ppluGFP = pd.DataFrame.from_dict(aa_median0_ppluGFP, orient='index')
aa_median1_ppluGFP = pd.DataFrame.from_dict(aa_median1_ppluGFP, orient='index')
aa_median2_ppluGFP = pd.DataFrame.from_dict(aa_median2_ppluGFP, orient='index')
aa_median3_ppluGFP = pd.DataFrame.from_dict(aa_median3_ppluGFP, orient='index')
aa_median4_ppluGFP = pd.DataFrame.from_dict(aa_median4_ppluGFP, orient='index')
aa_median5_ppluGFP = pd.DataFrame.from_dict(aa_median5_ppluGFP, orient='index')

result_median_ppluGFP = pd.concat([aa_median_ppluGFP, aa_median0_ppluGFP, aa_median1_ppluGFP, aa_median2_ppluGFP, aa_median3_ppluGFP, aa_median4_ppluGFP, aa_median5_ppluGFP], axis=1, sort=False)
result_median_ppluGFP.columns =['Median', '0 Mutations', '1 Mutation', '2 Mutations', '3 Mutations', '4 Mutations', '5 Mutations']
result_median_ppluGFP = result_median_ppluGFP.rename_axis('Position').reset_index()

result_median_ppluGFP

# %% [markdown]
# ## **<font color=green>Global</font>**

# %%
figure, axes = plt.subplots(3,1, figsize=(20,30))

result_median_amacGFP.plot(kind='scatter', x='Median', y='0 Mutations', color='grey', label='0 Mutations', s=10, alpha=0.5, ax=axes[0])
result_median_amacGFP.plot(kind='scatter', x='Median', y='1 Mutation', color='orange', label='1 Mutation', s=10, alpha=0.5, ax=axes[0])
result_median_amacGFP.plot(kind='scatter', x='Median', y='2 Mutations', color='red', label='2 Mutations', s=10, alpha=0.5, ax=axes[0])  
result_median_amacGFP.plot(kind='scatter', x='Median', y='3 Mutations', color='purple', label='3 Mutations', s=10, alpha=0.5, ax=axes[0])  
result_median_amacGFP.plot(kind='scatter', x='Median', y='4 Mutations', color='royalblue', label='4 Mutations', s=10, alpha=0.5, ax=axes[0])
result_median_amacGFP.plot(kind='scatter', x='Median', y='5 Mutations', color='green', label='5 Mutations', s=10, alpha=0.5, ax=axes[0])  
axes[0].set_title('amacGFP')


result_median_cgreGFP.plot(kind='scatter', x='Median', y='0 Mutations', color='grey', label='0 Mutations', s=10, alpha=0.5, ax=axes[1])
result_median_cgreGFP.plot(kind='scatter', x='Median', y='1 Mutation', color='orange', label='1 Mutation', s=10, alpha=0.5, ax=axes[1])
result_median_cgreGFP.plot(kind='scatter', x='Median', y='2 Mutations', color='red', label='2 Mutations', s=10, alpha=0.5, ax=axes[1])  
result_median_cgreGFP.plot(kind='scatter', x='Median', y='3 Mutations', color='purple', label='3 Mutations', s=10, alpha=0.5, ax=axes[1])  
result_median_cgreGFP.plot(kind='scatter', x='Median', y='4 Mutations', color='royalblue', label='4 Mutations', s=10, alpha=0.5, ax=axes[1])
result_median_cgreGFP.plot(kind='scatter', x='Median', y='5 Mutations', color='green', label='5 Mutations', s=10, alpha=0.5, ax=axes[1])  
axes[1].set_title('cgreGFP')


result_median_ppluGFP.plot(kind='scatter', x='Median', y='0 Mutations', color='grey', label='0 Mutations', s=10, alpha=0.5, ax=axes[2])
result_median_ppluGFP.plot(kind='scatter', x='Median', y='1 Mutation', color='orange', label='1 Mutation', s=10, alpha=0.5, ax=axes[2]) 
result_median_ppluGFP.plot(kind='scatter', x='Median', y='2 Mutations', color='red', label='2 Mutations', s=10, alpha=0.5, ax=axes[2])  
result_median_ppluGFP.plot(kind='scatter', x='Median', y='3 Mutations', color='purple', label='3 Mutations', s=10, alpha=0.5, ax=axes[2])  
result_median_ppluGFP.plot(kind='scatter', x='Median', y='4 Mutations', color='royalblue', label='4 Mutations', s=10, alpha=0.5, ax=axes[2])
result_median_ppluGFP.plot(kind='scatter', x='Median', y='5 Mutations', color='green', label='5 Mutations', s=10, alpha=0.5, ax=axes[2])  
axes[2].set_title('ppluGFP')

for ax in axes.flat:
    ax.set(xlabel='Median brightness codon', ylabel='Median brightness codon')

plt.savefig('Syn_mut_global_median_new.png', dpi=300)

# %% [markdown]
# ### **<font color=orange>Correlation: Mean</font>**

# %%
mean_amacGFP = result_average_amacGFP["Average"]
mut_0_amacGFP = result_average_amacGFP["0 Mutations"]
mut_1_amacGFP = result_average_amacGFP["1 Mutation"]
mut_2_amacGFP = result_average_amacGFP["2 Mutations"]
mut_3_amacGFP = result_average_amacGFP["3 Mutations"]
mut_4_amacGFP = result_average_amacGFP["4 Mutations"]
mut_5_amacGFP = result_average_amacGFP["5 Mutations"]

corrP_0_amacGFP = mean_amacGFP.corr(mut_0_amacGFP, method='pearson')
corrP_1_amacGFP = mean_amacGFP.corr(mut_1_amacGFP, method='pearson')
corrP_2_amacGFP = mean_amacGFP.corr(mut_2_amacGFP, method='pearson')
corrP_3_amacGFP = mean_amacGFP.corr(mut_3_amacGFP, method='pearson')
corrP_4_amacGFP = mean_amacGFP.corr(mut_4_amacGFP, method='pearson')
corrP_5_amacGFP = mean_amacGFP.corr(mut_5_amacGFP, method='pearson')

corrS_0_amacGFP = mean_amacGFP.corr(mut_0_amacGFP, method='spearman')
corrS_1_amacGFP = mean_amacGFP.corr(mut_1_amacGFP, method='spearman')
corrS_2_amacGFP = mean_amacGFP.corr(mut_2_amacGFP, method='spearman')
corrS_3_amacGFP = mean_amacGFP.corr(mut_3_amacGFP, method='spearman')
corrS_4_amacGFP = mean_amacGFP.corr(mut_4_amacGFP, method='spearman')
corrS_5_amacGFP = mean_amacGFP.corr(mut_5_amacGFP, method='spearman')

# %%
mean_cgreGFP = result_average_cgreGFP["Average"]
mut_0_cgreGFP = result_average_cgreGFP["0 Mutations"]
mut_1_cgreGFP = result_average_cgreGFP["1 Mutation"]
mut_2_cgreGFP = result_average_cgreGFP["2 Mutations"]
mut_3_cgreGFP = result_average_cgreGFP["3 Mutations"]
mut_4_cgreGFP = result_average_cgreGFP["4 Mutations"]
mut_5_cgreGFP = result_average_cgreGFP["5 Mutations"]

corrP_0_cgreGFP = mean_cgreGFP.corr(mut_0_cgreGFP, method='pearson')
corrP_1_cgreGFP = mean_cgreGFP.corr(mut_1_cgreGFP, method='pearson')
corrP_2_cgreGFP = mean_cgreGFP.corr(mut_2_cgreGFP, method='pearson')
corrP_3_cgreGFP = mean_cgreGFP.corr(mut_3_cgreGFP, method='pearson')
corrP_4_cgreGFP = mean_cgreGFP.corr(mut_4_cgreGFP, method='pearson')
corrP_5_cgreGFP = mean_cgreGFP.corr(mut_5_cgreGFP, method='pearson')

corrS_0_cgreGFP = mean_cgreGFP.corr(mut_0_cgreGFP, method='spearman')
corrS_1_cgreGFP = mean_cgreGFP.corr(mut_1_cgreGFP, method='spearman')
corrS_2_cgreGFP = mean_cgreGFP.corr(mut_2_cgreGFP, method='spearman')
corrS_3_cgreGFP = mean_cgreGFP.corr(mut_3_cgreGFP, method='spearman')
corrS_4_cgreGFP = mean_cgreGFP.corr(mut_4_cgreGFP, method='spearman')
corrS_5_cgreGFP = mean_cgreGFP.corr(mut_5_cgreGFP, method='spearman')

# %%
mean_ppluGFP = result_average_ppluGFP["Average"]
mut_0_ppluGFP = result_average_ppluGFP["0 Mutations"]
mut_1_ppluGFP = result_average_ppluGFP["1 Mutation"]
mut_2_ppluGFP = result_average_ppluGFP["2 Mutations"]
mut_3_ppluGFP = result_average_ppluGFP["3 Mutations"]
mut_4_ppluGFP = result_average_ppluGFP["4 Mutations"]
mut_5_ppluGFP = result_average_ppluGFP["5 Mutations"]

corrP_0_ppluGFP = mean_ppluGFP.corr(mut_0_ppluGFP, method='pearson')
corrP_1_ppluGFP = mean_ppluGFP.corr(mut_1_ppluGFP, method='pearson')
corrP_2_ppluGFP = mean_ppluGFP.corr(mut_2_ppluGFP, method='pearson')
corrP_3_ppluGFP = mean_ppluGFP.corr(mut_3_ppluGFP, method='pearson')
corrP_4_ppluGFP = mean_ppluGFP.corr(mut_4_ppluGFP, method='pearson')
corrP_5_ppluGFP = mean_ppluGFP.corr(mut_5_ppluGFP, method='pearson')

corrS_0_ppluGFP = mean_ppluGFP.corr(mut_0_ppluGFP, method='spearman')
corrS_1_ppluGFP = mean_ppluGFP.corr(mut_1_ppluGFP, method='spearman')
corrS_2_ppluGFP = mean_ppluGFP.corr(mut_2_ppluGFP, method='spearman')
corrS_3_ppluGFP = mean_ppluGFP.corr(mut_3_ppluGFP, method='spearman')
corrS_4_ppluGFP = mean_ppluGFP.corr(mut_4_ppluGFP, method='spearman')
corrS_5_ppluGFP = mean_ppluGFP.corr(mut_5_ppluGFP, method='spearman')

# %%
figure, axes = plt.subplots(3,1, figsize=(20,30))

result_average_amacGFP.plot(kind='scatter', x='Average', y='0 Mutations', color='grey', label='0 Mutations, CC: P={} S={}'.format(corrP_0_amacGFP,corrS_0_amacGFP), s=10, alpha=0.5, ax=axes[0])
result_average_amacGFP.plot(kind='scatter', x='Average', y='1 Mutation', color='orange', label='1 Mutation, CC: P={} S={}'.format(corrP_1_amacGFP,corrS_1_amacGFP), s=10, alpha=0.5, ax=axes[0])
result_average_amacGFP.plot(kind='scatter', x='Average', y='2 Mutations', color='red', label='2 Mutations, CC: P={} S={}'.format(corrP_2_amacGFP,corrS_2_amacGFP), s=10, alpha=0.5, ax=axes[0])  
result_average_amacGFP.plot(kind='scatter', x='Average', y='3 Mutations', color='purple', label='3 Mutations, CC: P={} S={}'.format(corrP_3_amacGFP,corrS_3_amacGFP), s=10, alpha=0.5, ax=axes[0])  
result_average_amacGFP.plot(kind='scatter', x='Average', y='4 Mutations', color='royalblue', label='4 Mutations, CC: P={} S={}'.format(corrP_4_amacGFP,corrS_4_amacGFP), s=10, alpha=0.5, ax=axes[0])
result_average_amacGFP.plot(kind='scatter', x='Average', y='5 Mutations', color='green', label='5 Mutations, CC: P={} S={}'.format(corrP_5_amacGFP,corrS_5_amacGFP), s=10, alpha=0.5, ax=axes[0])  
axes[0].set_title('amacGFP')


result_average_cgreGFP.plot(kind='scatter', x='Average', y='0 Mutations', color='grey', label='0 Mutations, CC: P={} S={}'.format(corrP_0_cgreGFP,corrS_0_cgreGFP), s=10, alpha=0.5, ax=axes[1])
result_average_cgreGFP.plot(kind='scatter', x='Average', y='1 Mutation', color='orange', label='1 Mutation, CC: P={} S={}'.format(corrP_1_cgreGFP,corrS_1_cgreGFP), s=10, alpha=0.5, ax=axes[1])
result_average_cgreGFP.plot(kind='scatter', x='Average', y='2 Mutations', color='red', label='2 Mutations, CC: P={} S={}'.format(corrP_2_cgreGFP,corrS_2_cgreGFP), s=10, alpha=0.5, ax=axes[1])  
result_average_cgreGFP.plot(kind='scatter', x='Average', y='3 Mutations', color='purple', label='3 Mutations, CC: P={} S={}'.format(corrP_3_cgreGFP,corrS_3_cgreGFP), s=10, alpha=0.5, ax=axes[1])  
result_average_cgreGFP.plot(kind='scatter', x='Average', y='4 Mutations', color='royalblue', label='4 Mutations, CC: P={} S={}'.format(corrP_4_cgreGFP,corrS_4_cgreGFP), s=10, alpha=0.5, ax=axes[1])
result_average_cgreGFP.plot(kind='scatter', x='Average', y='5 Mutations', color='green', label='5 Mutations, CC: P={} S={}'.format(corrP_5_cgreGFP,corrS_5_cgreGFP), s=10, alpha=0.5, ax=axes[1])  
axes[1].set_title('cgreGFP')


result_average_ppluGFP.plot(kind='scatter', x='Average', y='0 Mutations', color='grey', label='0 Mutations, CC: P={} S={}'.format(corrP_0_ppluGFP,corrS_0_ppluGFP), s=10, alpha=0.5, ax=axes[2])
result_average_ppluGFP.plot(kind='scatter', x='Average', y='1 Mutation', color='orange', label='1 Mutation, CC: P={} S={}'.format(corrP_1_ppluGFP,corrS_1_ppluGFP), s=10, alpha=0.5, ax=axes[2]) 
result_average_ppluGFP.plot(kind='scatter', x='Average', y='2 Mutations', color='red', label='2 Mutations, CC: P={} S={}'.format(corrP_2_ppluGFP,corrS_2_ppluGFP), s=10, alpha=0.5, ax=axes[2])  
result_average_ppluGFP.plot(kind='scatter', x='Average', y='3 Mutations', color='purple', label='3 Mutations, CC: P={} S={}'.format(corrP_3_ppluGFP,corrS_3_ppluGFP), s=10, alpha=0.5, ax=axes[2])  
result_average_ppluGFP.plot(kind='scatter', x='Average', y='4 Mutations', color='royalblue', label='4 Mutations, CC: P={} S={}'.format(corrP_4_ppluGFP,corrS_4_ppluGFP), s=10, alpha=0.5, ax=axes[2])
result_average_ppluGFP.plot(kind='scatter', x='Average', y='5 Mutations', color='green', label='5 Mutations, CC: P={} S={}'.format(corrP_5_ppluGFP,corrS_5_ppluGFP), s=10, alpha=0.5, ax=axes[2])  
axes[2].set_title('ppluGFP')

for ax in axes.flat:
    ax.set(xlabel='Mean brightness codon', ylabel='Mean brightness codon')

plt.savefig('Syn_mut_global_mean_corr_new.png', dpi=300)

# %% [markdown]
# ### **<font color=orange>Correlation: Median</font>**

# %%
median_amacGFP = result_median_amacGFP["Median"]
mut_0_amacGFP = result_median_amacGFP["0 Mutations"]
mut_1_amacGFP = result_median_amacGFP["1 Mutation"]
mut_2_amacGFP = result_median_amacGFP["2 Mutations"]
mut_3_amacGFP = result_median_amacGFP["3 Mutations"]
mut_4_amacGFP = result_median_amacGFP["4 Mutations"]
mut_5_amacGFP = result_median_amacGFP["5 Mutations"]

corrP_0_amacGFP = median_amacGFP.corr(mut_0_amacGFP, method='pearson')
corrP_1_amacGFP = median_amacGFP.corr(mut_1_amacGFP, method='pearson')
corrP_2_amacGFP = median_amacGFP.corr(mut_2_amacGFP, method='pearson')
corrP_3_amacGFP = median_amacGFP.corr(mut_3_amacGFP, method='pearson')
corrP_4_amacGFP = median_amacGFP.corr(mut_4_amacGFP, method='pearson')
corrP_5_amacGFP = median_amacGFP.corr(mut_5_amacGFP, method='pearson')

corrS_0_amacGFP = median_amacGFP.corr(mut_0_amacGFP, method='spearman')
corrS_1_amacGFP = median_amacGFP.corr(mut_1_amacGFP, method='spearman')
corrS_2_amacGFP = median_amacGFP.corr(mut_2_amacGFP, method='spearman')
corrS_3_amacGFP = median_amacGFP.corr(mut_3_amacGFP, method='spearman')
corrS_4_amacGFP = median_amacGFP.corr(mut_4_amacGFP, method='spearman')
corrS_5_amacGFP = median_amacGFP.corr(mut_5_amacGFP, method='spearman')

# %%
median_cgreGFP = result_median_cgreGFP["Median"]
mut_0_cgreGFP = result_median_cgreGFP["0 Mutations"]
mut_1_cgreGFP = result_median_cgreGFP["1 Mutation"]
mut_2_cgreGFP = result_median_cgreGFP["2 Mutations"]
mut_3_cgreGFP = result_median_cgreGFP["3 Mutations"]
mut_4_cgreGFP = result_median_cgreGFP["4 Mutations"]
mut_5_cgreGFP = result_median_cgreGFP["5 Mutations"]

corrP_0_cgreGFP = median_cgreGFP.corr(mut_0_cgreGFP, method='pearson')
corrP_1_cgreGFP = median_cgreGFP.corr(mut_1_cgreGFP, method='pearson')
corrP_2_cgreGFP = median_cgreGFP.corr(mut_2_cgreGFP, method='pearson')
corrP_3_cgreGFP = median_cgreGFP.corr(mut_3_cgreGFP, method='pearson')
corrP_4_cgreGFP = median_cgreGFP.corr(mut_4_cgreGFP, method='pearson')
corrP_5_cgreGFP = median_cgreGFP.corr(mut_5_cgreGFP, method='pearson')

corrS_0_cgreGFP = median_cgreGFP.corr(mut_0_cgreGFP, method='spearman')
corrS_1_cgreGFP = median_cgreGFP.corr(mut_1_cgreGFP, method='spearman')
corrS_2_cgreGFP = median_cgreGFP.corr(mut_2_cgreGFP, method='spearman')
corrS_3_cgreGFP = median_cgreGFP.corr(mut_3_cgreGFP, method='spearman')
corrS_4_cgreGFP = median_cgreGFP.corr(mut_4_cgreGFP, method='spearman')
corrS_5_cgreGFP = median_cgreGFP.corr(mut_5_cgreGFP, method='spearman')

# %%
median_ppluGFP = result_median_ppluGFP["Median"]
mut_0_ppluGFP = result_median_ppluGFP["0 Mutations"]
mut_1_ppluGFP = result_median_ppluGFP["1 Mutation"]
mut_2_ppluGFP = result_median_ppluGFP["2 Mutations"]
mut_3_ppluGFP = result_median_ppluGFP["3 Mutations"]
mut_4_ppluGFP = result_median_ppluGFP["4 Mutations"]
mut_5_ppluGFP = result_median_ppluGFP["5 Mutations"]

corrP_0_ppluGFP = median_ppluGFP.corr(mut_0_ppluGFP, method='pearson')
corrP_1_ppluGFP = median_ppluGFP.corr(mut_1_ppluGFP, method='pearson')
corrP_2_ppluGFP = median_ppluGFP.corr(mut_2_ppluGFP, method='pearson')
corrP_3_ppluGFP = median_ppluGFP.corr(mut_3_ppluGFP, method='pearson')
corrP_4_ppluGFP = median_ppluGFP.corr(mut_4_ppluGFP, method='pearson')
corrP_5_ppluGFP = median_ppluGFP.corr(mut_5_ppluGFP, method='pearson')

corrS_0_ppluGFP = median_ppluGFP.corr(mut_0_ppluGFP, method='spearman')
corrS_1_ppluGFP = median_ppluGFP.corr(mut_1_ppluGFP, method='spearman')
corrS_2_ppluGFP = median_ppluGFP.corr(mut_2_ppluGFP, method='spearman')
corrS_3_ppluGFP = median_ppluGFP.corr(mut_3_ppluGFP, method='spearman')
corrS_4_ppluGFP = median_ppluGFP.corr(mut_4_ppluGFP, method='spearman')
corrS_5_ppluGFP = median_ppluGFP.corr(mut_5_ppluGFP, method='spearman')

# %%
figure, axes = plt.subplots(3,1, figsize=(20,30))

result_median_amacGFP.plot(kind='scatter', x='Median', y='0 Mutations', color='grey', label='0 Mutations, CC: P={} S={}'.format(corrP_0_amacGFP,corrS_0_amacGFP), s=10, alpha=0.5, ax=axes[0])
result_median_amacGFP.plot(kind='scatter', x='Median', y='1 Mutation', color='orange', label='1 Mutation, CC: P={} S={}'.format(corrP_1_amacGFP,corrS_1_amacGFP), s=10, alpha=0.5, ax=axes[0])
result_median_amacGFP.plot(kind='scatter', x='Median', y='2 Mutations', color='red', label='2 Mutations, CC: P={} S={}'.format(corrP_2_amacGFP,corrS_2_amacGFP), s=10, alpha=0.5, ax=axes[0])  
result_median_amacGFP.plot(kind='scatter', x='Median', y='3 Mutations', color='purple', label='3 Mutations, CC: P={} S={}'.format(corrP_3_amacGFP,corrS_3_amacGFP), s=10, alpha=0.5, ax=axes[0])  
result_median_amacGFP.plot(kind='scatter', x='Median', y='4 Mutations', color='royalblue', label='4 Mutations, CC: P={} S={}'.format(corrP_4_amacGFP,corrS_4_amacGFP), s=10, alpha=0.5, ax=axes[0])
result_median_amacGFP.plot(kind='scatter', x='Median', y='5 Mutations', color='green', label='5 Mutations, CC: P={} S={}'.format(corrP_5_amacGFP,corrS_5_amacGFP), s=10, alpha=0.5, ax=axes[0])  
axes[0].set_title('amacGFP')


result_median_cgreGFP.plot(kind='scatter', x='Median', y='0 Mutations', color='grey', label='0 Mutations, CC: P={} S={}'.format(corrP_0_cgreGFP,corrS_0_cgreGFP), s=10, alpha=0.5, ax=axes[1])
result_median_cgreGFP.plot(kind='scatter', x='Median', y='1 Mutation', color='orange', label='1 Mutation, CC: P={} S={}'.format(corrP_1_cgreGFP,corrS_1_cgreGFP), s=10, alpha=0.5, ax=axes[1])
result_median_cgreGFP.plot(kind='scatter', x='Median', y='2 Mutations', color='red', label='2 Mutations, CC: P={} S={}'.format(corrP_2_cgreGFP,corrS_2_cgreGFP), s=10, alpha=0.5, ax=axes[1])  
result_median_cgreGFP.plot(kind='scatter', x='Median', y='3 Mutations', color='purple', label='3 Mutations, CC: P={} S={}'.format(corrP_3_cgreGFP,corrS_3_cgreGFP), s=10, alpha=0.5, ax=axes[1])  
result_median_cgreGFP.plot(kind='scatter', x='Median', y='4 Mutations', color='royalblue', label='4 Mutations, CC: P={} S={}'.format(corrP_4_cgreGFP,corrS_4_cgreGFP), s=10, alpha=0.5, ax=axes[1])
result_median_cgreGFP.plot(kind='scatter', x='Median', y='5 Mutations', color='green', label='5 Mutations, CC: P={} S={}'.format(corrP_5_cgreGFP,corrS_5_cgreGFP), s=10, alpha=0.5, ax=axes[1])  
axes[1].set_title('cgreGFP')


result_median_ppluGFP.plot(kind='scatter', x='Median', y='0 Mutations', color='grey', label='0 Mutations, CC: P={} S={}'.format(corrP_0_ppluGFP,corrS_0_ppluGFP), s=10, alpha=0.5, ax=axes[2])
result_median_ppluGFP.plot(kind='scatter', x='Median', y='1 Mutation', color='orange', label='1 Mutation, CC: P={} S={}'.format(corrP_1_ppluGFP,corrS_1_ppluGFP), s=10, alpha=0.5, ax=axes[2]) 
result_median_ppluGFP.plot(kind='scatter', x='Median', y='2 Mutations', color='red', label='2 Mutations, CC: P={} S={}'.format(corrP_2_ppluGFP,corrS_2_ppluGFP), s=10, alpha=0.5, ax=axes[2])  
result_median_ppluGFP.plot(kind='scatter', x='Median', y='3 Mutations', color='purple', label='3 Mutations, CC: P={} S={}'.format(corrP_3_ppluGFP,corrS_3_ppluGFP), s=10, alpha=0.5, ax=axes[2])  
result_median_ppluGFP.plot(kind='scatter', x='Median', y='4 Mutations', color='royalblue', label='4 Mutations, CC: P={} S={}'.format(corrP_4_ppluGFP,corrS_4_ppluGFP), s=10, alpha=0.5, ax=axes[2])
result_median_ppluGFP.plot(kind='scatter', x='Median', y='5 Mutations', color='green', label='5 Mutations, CC: P={} S={}'.format(corrP_5_ppluGFP,corrS_5_ppluGFP), s=10, alpha=0.5, ax=axes[2])  
axes[2].set_title('ppluGFP')

for ax in axes.flat:
    ax.set(xlabel='Median brightness codon', ylabel='Median brightness codon')

plt.savefig('Syn_mut_global_median_corr_new.png', dpi=300)

# %% [markdown]
# ## **<font color=purple>Study of WT</font>**

# %%
import matplotlib.lines as mlines

amac_marker = mlines.Line2D([], [], color='deepskyblue', marker='o',
                          markersize=10, label='amacGFP')
cgre_marker = mlines.Line2D([], [], color='deeppink', marker='o',
                          markersize=10, label='cgreGFP')
pplu_marker = mlines.Line2D([], [], color='blueviolet', marker='o',
                          markersize=10, label='ppluGFP')

# %%
#From the previously created dataset, select the data for the wt amacGFP gene (as a first try with the simplest aa genotype)

wt_mut_amacGFP = aa_mut_amacGFP[aa_mut_amacGFP.aa_genotype_pseudo=='wt']
wt_mut_amacGFP.reset_index(inplace=True)

wt_mut_amacGFP
# Out:
#       level_0  index     gene aa_genotype_pseudo        nt_genotype  \
# 0       44534  44534  amacGFP                 wt              A227G
# 1       44535  44535  amacGFP                 wt        A227G:C278T
# 2       44536  44536  amacGFP                 wt  A227G:C575G:C677G
# 3       44537  44537  amacGFP                 wt        A227G:C677A
# 4       44538  44538  amacGFP                 wt        A227G:G488T
# ...       ...    ...      ...                ...                ...
# 1084    45618  45618  amacGFP                 wt              T689C
# 1085    45619  45619  amacGFP                 wt        T689C:C705T
# 1086    45620  45620  amacGFP                 wt              T689G
# 1087    45621  45621  amacGFP                 wt        T689G:C710T
# 1088    45622  45622  amacGFP                 wt                 wt
#
#       total_cell_count  n_replicates  replicates_stdev_weighted  \
# 0               730.88          51.0                1387.035958
# ...

# %%
wt_bright_amacGFP = wt_mut_amacGFP.copy()
wt_bright_amacGFP['replicates_mean_brightness']=wt_bright_amacGFP['replicates_mean_brightness'].apply(lambda x: x/1.1793308925118149)

wt_bright_amacGFP
# Out:
#       level_0  index     gene aa_genotype_pseudo        nt_genotype  \
# 0       44534  44534  amacGFP                 wt              A227G
# 1       44535  44535  amacGFP                 wt        A227G:C278T
# 2       44536  44536  amacGFP                 wt  A227G:C575G:C677G
# 3       44537  44537  amacGFP                 wt        A227G:C677A
# 4       44538  44538  amacGFP                 wt        A227G:G488T
# ...       ...    ...      ...                ...                ...
# 1084    45618  45618  amacGFP                 wt              T689C
# 1085    45619  45619  amacGFP                 wt        T689C:C705T
# 1086    45620  45620  amacGFP                 wt              T689G
# 1087    45621  45621  amacGFP                 wt        T689G:C710T
# 1088    45622  45622  amacGFP                 wt                 wt
#
#       total_cell_count  n_replicates  replicates_stdev_weighted  \
# 0               730.88          51.0                1387.035958
# ...

# %%
wt_mut_cgreGFP = aa_mut_cgreGFP[aa_mut_cgreGFP.aa_genotype_pseudo=='wt']
wt_mut_cgreGFP.reset_index(inplace=True)

wt_mut_cgreGFP
# Out:
#       level_0  index     gene aa_genotype_pseudo             nt_genotype  \
# 0       32194  77817  cgreGFP                 wt                    A17G
# 1       32195  77818  cgreGFP                 wt  A17G:A335G:C470T:C704A
# 2       32196  77819  cgreGFP                 wt        A17G:A335G:T464A
# 3       32197  77820  cgreGFP                 wt        A17G:C170T:A629G
# 4       32198  77821  cgreGFP                 wt              A17G:C320T
# ...       ...    ...      ...                ...                     ...
# 1583    33777  79400  cgreGFP                 wt              T95C:G593A
# 1584    33778  79401  cgreGFP                 wt              T95C:T242C
# 1585    33779  79402  cgreGFP                 wt        T95C:T242C:A449T
# 1586    33780  79403  cgreGFP                 wt        T95C:T542C:A608C
# 1587    33781  79404  cgreGFP                 wt                      wt
#
#       total_cell_count  n_replicates  replicates_stdev_weighted  \
# ...

# %%
wt_bright_cgreGFP = wt_mut_cgreGFP.copy()
wt_bright_cgreGFP['replicates_mean_brightness']=wt_bright_cgreGFP['replicates_mean_brightness'].apply(lambda x: x/1.3706405019099068)
wt_bright_cgreGFP
# Out:
#       level_0  index     gene aa_genotype_pseudo             nt_genotype  \
# 0       32194  77817  cgreGFP                 wt                    A17G
# 1       32195  77818  cgreGFP                 wt  A17G:A335G:C470T:C704A
# 2       32196  77819  cgreGFP                 wt        A17G:A335G:T464A
# 3       32197  77820  cgreGFP                 wt        A17G:C170T:A629G
# 4       32198  77821  cgreGFP                 wt              A17G:C320T
# ...       ...    ...      ...                ...                     ...
# 1583    33777  79400  cgreGFP                 wt              T95C:G593A
# 1584    33778  79401  cgreGFP                 wt              T95C:T242C
# 1585    33779  79402  cgreGFP                 wt        T95C:T242C:A449T
# 1586    33780  79403  cgreGFP                 wt        T95C:T542C:A608C
# 1587    33781  79404  cgreGFP                 wt                      wt
#
#       total_cell_count  n_replicates  replicates_stdev_weighted  \
# ...

# %%
wt_mut_ppluGFP = aa_mut_ppluGFP[aa_mut_ppluGFP.aa_genotype_pseudo=='wt']
wt_mut_ppluGFP.reset_index(inplace=True)

wt_mut_ppluGFP
# Out:
#       level_0   index     gene aa_genotype_pseudo              nt_genotype  \
# 0       44396  123801  ppluGFP                 wt                    A125G
# 1       44397  123802  ppluGFP                 wt              A125G:A251T
# 2       44398  123803  ppluGFP                 wt              A125G:A296G
# 3       44399  123804  ppluGFP                 wt              A125G:A296T
# 4       44400  123805  ppluGFP                 wt  A125G:A299G:G320T:A614G
# ...       ...     ...      ...                ...                      ...
# 2760    47156  126561  ppluGFP                 wt                    T659A
# 2761    47157  126562  ppluGFP                 wt              T659A:C662T
# 2762    47158  126563  ppluGFP                 wt                    T659C
# 2763    47159  126564  ppluGFP                 wt                    T659G
# 2764    47160  126565  ppluGFP                 wt                       wt
#
#       total_cell_count  n_replicates  replicates_stdev_weighted  \
# ...

# %%
wt_bright_ppluGFP = wt_mut_ppluGFP.copy()
wt_bright_ppluGFP['replicates_mean_brightness']=wt_bright_ppluGFP['replicates_mean_brightness'].apply(lambda x: x/1.2775111106220145)
wt_bright_ppluGFP
# Out:
#       level_0   index     gene aa_genotype_pseudo              nt_genotype  \
# 0       44396  123801  ppluGFP                 wt                    A125G
# 1       44397  123802  ppluGFP                 wt              A125G:A251T
# 2       44398  123803  ppluGFP                 wt              A125G:A296G
# 3       44399  123804  ppluGFP                 wt              A125G:A296T
# 4       44400  123805  ppluGFP                 wt  A125G:A299G:G320T:A614G
# ...       ...     ...      ...                ...                      ...
# 2760    47156  126561  ppluGFP                 wt                    T659A
# 2761    47157  126562  ppluGFP                 wt              T659A:C662T
# 2762    47158  126563  ppluGFP                 wt                    T659C
# 2763    47159  126564  ppluGFP                 wt                    T659G
# 2764    47160  126565  ppluGFP                 wt                       wt
#
#       total_cell_count  n_replicates  replicates_stdev_weighted  \
# ...

# %% [markdown]
# ### **<font color=orange>Not normalized</font>**

# %%
plt.figure(figsize=(40,40))

for gene, dataset, i, color in [('amacGFP', wt_mut_amacGFP, 1, 'deepskyblue'),('cgreGFP', wt_mut_cgreGFP, 2, 'deeppink'),('ppluGFP', wt_mut_ppluGFP, 3, 'blueviolet')]:
    plt.subplot(3,1,i)
    plt.ylabel('Mean brightness', size=20)
    plt.xlabel('Nucleotide position in the genome', size=20)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.minorticks_on()
    plt.grid(b=True, which='major', linestyle='-')
    plt.grid(b=True, which='minor', linestyle='--')
    for index, row in dataset.iterrows(): 
            if ':' not in row["nt_genotype"]:
                try:
                    position_wt = int(row["nt_genotype"][1:-1])
                    brightness_wt = row["replicates_mean_brightness"]
                    plt.plot(position_wt, brightness_wt, marker = 'o', color=color, markersize=10)
                    plt.title(gene, size=30)
                except IndexError:
                    pass
                except ValueError:
                    pass

plt.tight_layout()
plt.savefig('WT_separate.png', dpi=300)

# %%
plt.figure(figsize=(22,11))

for gene, dataset, i, color in [('amacGFP', wt_mut_amacGFP, 1, 'deepskyblue'),('cgreGFP', wt_mut_cgreGFP, 2, 'deeppink'),('ppluGFP', wt_mut_ppluGFP, 3, 'blueviolet')]:
    plt.ylabel('Mean brightness', size=20)
    plt.xlabel('Nucleotide position in the genome', size=20)
    plt.title('Analysis of synonymous mutations in wild-type genes', fontsize=30)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    
    plt.xticks(np.arange(0, 800, step=50));
    plt.yticks(np.arange(3.8, 4.7, step=0.1));

    plt.xlim(xmin=-20,xmax=770)
    plt.ylim(ymin=3.75,ymax=4.65)
    
    #plt.minorticks_on()
    plt.grid(alpha=0.5)
    #plt.grid(b=True, which='major', linestyle='-')
    #plt.grid(b=True, which='minor', linestyle='--')
    for index, row in dataset.iterrows(): 
            if ':' not in row["nt_genotype"]:
                try:
                    position_wt = int(row["nt_genotype"][1:-1])
                    brightness_wt = (row["replicates_mean_brightness"])
                    plt.plot(position_wt, brightness_wt, marker = 'o', color=color, markersize=5)
                except IndexError:
                    pass
                except ValueError:
                    pass

plt.tight_layout()


plt.legend(handles=[amac_marker, cgre_marker, pplu_marker], fontsize=20, loc='lower right')
plt.savefig('WT.png', dpi=300)

# %% [markdown]
# ### **<font color=orange>Normalized</font>**

# %%
plt.figure(figsize=(22,11))

for gene, dataset, i, color in [('amacGFP', wt_mut_amacGFP, 1, 'deepskyblue'),('cgreGFP', wt_mut_cgreGFP, 2, 'deeppink'),('ppluGFP', wt_mut_ppluGFP, 3, 'blueviolet')]:
    plt.ylabel('Mean brightness', size=20)
    plt.xlabel('Nucleotide position in the genome', size=20)
    plt.title('Analysis of synonymous mutations in wild-type genes (normalised)', fontsize=30)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    
    plt.xticks(np.arange(0, 800, step=50));
    plt.yticks(np.arange(0.97, 1.04, step=0.01));

    plt.xlim(xmin=-20,xmax=770)
    plt.ylim(ymin=0.969,ymax=1.041)

    #plt.minorticks_on()
    plt.grid(alpha=0.5)
    for index, row in dataset.iterrows(): 
            if ':' not in row["nt_genotype"]:
                try:
                    position_wt = int(row["nt_genotype"][1:-1])
                    brightness_wt = (row["replicates_mean_brightness"])/wt_brightness[gene]
                    plt.plot(position_wt, brightness_wt, marker = 'o', color=color, markersize=5)
                except IndexError:
                    pass
                except ValueError:
                    pass

plt.tight_layout()

plt.legend(handles=[amac_marker, cgre_marker, pplu_marker], fontsize=20)

plt.savefig('WT_norm1.png', dpi=300)

# %%
plt.figure(figsize=(30,20))

for gene, dataset, i, color in [('amacGFP', wt_bright_amacGFP, 1, 'deepskyblue'),('cgreGFP', wt_bright_cgreGFP, 2, 'deeppink'),('ppluGFP', wt_bright_ppluGFP, 3, 'blueviolet')]:
    plt.ylabel('Mean brightness', size=20)
    plt.xlabel('Nucleotide position in the genome', size=20)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.minorticks_on()
    plt.grid(b=True, which='major', linestyle='-')
    plt.grid(b=True, which='minor', linestyle='--')
    for index, row in dataset.iterrows(): 
            if ':' not in row["nt_genotype"]:
                try:
                    position_wt = int(row["nt_genotype"][1:-1])
                    brightness_wt = (row["replicates_mean_brightness"])
                    plt.plot(position_wt, brightness_wt, marker = 'o', color=color, markersize=10)
                except IndexError:
                    pass
                except ValueError:
                    pass

plt.tight_layout()

plt.legend(handles=[amac_marker, cgre_marker, pplu_marker])
plt.savefig('WT_norm2.png', dpi=300)

# %%
plt.figure(figsize=(50,50))

for gene, dataset, i, color in [('amacGFP', wt_mut_amacGFP, 1, 'deepskyblue'),('cgreGFP', wt_mut_cgreGFP, 2, 'deeppink'),('ppluGFP', wt_mut_ppluGFP, 3, 'blueviolet')]:
    plt.subplot(3,1,i)
    plt.ylabel('Mean brightness', size=20)
    plt.xlabel('Nucleotide position in the genome', size=20)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.minorticks_on()
    plt.grid(b=True, which='major', linestyle='-')
    plt.grid(b=True, which='minor', linestyle='--')
    for index, row in dataset.iterrows(): 
            if ':' not in row["nt_genotype"]:
                try:
                    position_wt = int(row["nt_genotype"][1:-1])
                    brightness_wt = row["replicates_mean_brightness"]/wt_brightness[gene]
                    plt.plot(position_wt, brightness_wt, marker = 'o', color=color, markersize=10)
                    plt.title(gene, size=30)
                except IndexError:
                    pass
                except ValueError:
                    pass

plt.tight_layout()
plt.savefig('WT_norm_separate.png', dpi=300)

# %% [markdown]
# ### **<font color=orange>Boxplot (not normalized)</font>**

# %%
position_wt_amacGFP = {}
brightness_wt_amacGFP = {}

for index, row in wt_bright_amacGFP.iterrows(): 
        if ':' not in row["nt_genotype"]:
            try:
                position_wt_amacGFP[index] = int(row["nt_genotype"][1:-1])
                brightness_wt_amacGFP[index] = row["replicates_mean_brightness"]
            except IndexError:
                pass
            except ValueError:
                pass

# %%
pos_wt_amacGFP = pd.DataFrame.from_dict(position_wt_amacGFP, orient='index')
bri_wt_amacGFP = pd.DataFrame.from_dict(brightness_wt_amacGFP, orient='index')
result_wt_amacGFP = pd.concat([pos_wt_amacGFP, bri_wt_amacGFP], axis=1, sort=False)
#result_amacGFP = result_amacGFP.dropna()
result_wt_amacGFP.columns =['Position', 'Brightness']
result_wt_amacGFP
# Out:
#       Position  Brightness
# 0          227    3.377457
# 5          269    3.373734
# 11         353    3.391209
# 13         353    3.377940
# 18         353    3.382591
# ...        ...         ...
# 1081       680    3.363385
# 1082       686    3.359819
# 1083       689    3.370399
# 1084       689    3.369288
# 1086       689    3.397255
#
# [409 rows x 2 columns]

# %%
position_wt_cgreGFP = {}
brightness_wt_cgreGFP = {}

for index, row in wt_bright_cgreGFP.iterrows(): 
        if ':' not in row["nt_genotype"]:
            try:
                position_wt_cgreGFP[index] = int(row["nt_genotype"][1:-1])
                brightness_wt_cgreGFP[index] = row["replicates_mean_brightness"]
            except IndexError:
                pass
            except ValueError:
                pass

# %%
pos_wt_cgreGFP = pd.DataFrame.from_dict(position_wt_cgreGFP, orient='index')
bri_wt_cgreGFP = pd.DataFrame.from_dict(brightness_wt_cgreGFP, orient='index')
result_wt_cgreGFP = pd.concat([pos_wt_cgreGFP, bri_wt_cgreGFP], axis=1, sort=False)
#result_cgreGFP = result_cgreGFP.dropna()
result_wt_cgreGFP.columns =['Position', 'Brightness']
result_wt_cgreGFP
# Out:
#       Position  Brightness
# 0           17    3.287761
# 11         194    3.284994
# 16         194    3.296491
# 18         227    3.280850
# 25         266    3.280228
# ...        ...         ...
# 1567       677    3.289866
# 1568       677    3.290996
# 1570       690    3.288076
# 1573        95    3.293775
# 1578        95    3.268523
#
# [387 rows x 2 columns]

# %%
position_wt_ppluGFP = {}
brightness_wt_ppluGFP = {}

for index, row in wt_bright_ppluGFP.iterrows(): 
        if ':' not in row["nt_genotype"]:
            try:
                position_wt_ppluGFP[index] = int(row["nt_genotype"][1:-1])
                brightness_wt_ppluGFP[index] = row["replicates_mean_brightness"]
            except IndexError:
                pass
            except ValueError:
                pass

# %%
pos_wt_ppluGFP = pd.DataFrame.from_dict(position_wt_ppluGFP, orient='index')
bri_wt_ppluGFP = pd.DataFrame.from_dict(brightness_wt_ppluGFP, orient='index')
result_wt_ppluGFP = pd.concat([pos_wt_ppluGFP, bri_wt_ppluGFP], axis=1, sort=False)
#result_cgreGFP = result_cgreGFP.dropna()
result_wt_ppluGFP.columns =['Position', 'Brightness']
result_wt_ppluGFP
# Out:
#       Position  Brightness
# 0          125    3.312812
# 15         131    3.299768
# 17         131    3.310262
# 33         131    3.286953
# 47          14    3.301749
# ...        ...         ...
# 2758       656    3.313451
# 2759       656    3.302471
# 2760       659    3.310481
# 2762       659    3.309460
# 2763       659    3.307731
#
# [431 rows x 2 columns]

# %%
import seaborn as sns

plt.figure(figsize=(50,50))
for gene, dataset, i, color in [('amacGFP', result_wt_amacGFP, 1, 'lawngreen'),('cgreGFP', result_wt_cgreGFP, 2, 'limegreen'),('ppluGFP', result_wt_ppluGFP, 3, 'green')]:
    plt.subplot(3,1,i)
    ax=sns.boxplot(x='Position', y='Brightness', data=dataset)#, hue=color), 
                #palette=['grey','orange', 'red', 'purple','royalblue','green'])
    ax.set_xlabel('Nucleotide position in the genome')
    ax.set_ylabel('Mean brightness')
    
    #ax.set_xticks(np.arange(0, 250, 5))
    plt.title(gene, size=30)

plt.tight_layout()
plt.savefig('Syn_mut_wt_box.png', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-e0b58d924768> in <module>
# ----> 1 import seaborn as sns
#       2
#       3 plt.figure(figsize=(50,50))
#       4 for gene, dataset, i, color in [('amacGFP', result_wt_amacGFP, 1, 'lawngreen'),('cgreGFP', result_wt_cgreGFP, 2, 'limegreen'),('ppluGFP', result_wt_ppluGFP, 3, 'green')]:
#       5     plt.subplot(3,1,i)
#
# ModuleNotFoundError: No module named 'seaborn'

# %% [markdown]
# ### **<font color=orange>Scatter plot (not normalized)</font>**

# %%
wt_pos_amacGFP = result_wt_amacGFP.Position.unique()
print(len(wt_pos_amacGFP))
# Out:
# 242

# %%
wt_median_amacGFP = {}
for pos in wt_pos_amacGFP:
    wt_median_amac = result_wt_amacGFP[result_wt_amacGFP.Position == pos]
    wt_median_amacGFP[pos] = wt_median_amac['Brightness'].median()

# %%
wt_median_amacGFP = pd.DataFrame.from_dict(wt_median_amacGFP, orient='index')
wt_median_amacGFP.columns =['Median']
wt_median_amacGFP = wt_median_amacGFP.rename_axis('Position').reset_index()
result_wt_median_amacGFP = result_wt_amacGFP.merge(wt_median_amacGFP, how='outer')
result_wt_median_amacGFP.columns =['Position', 'Brightness','Median']

result_wt_median_amacGFP
# Out:
#      Position  Brightness    Median
# 0         227    3.377457  3.377457
# 1         269    3.373734  3.373734
# 2         353    3.391209  3.382591
# 3         353    3.377940  3.382591
# 4         353    3.382591  3.382591
# ..        ...         ...       ...
# 404       680    3.363385  3.363385
# 405       686    3.359819  3.359819
# 406       689    3.370399  3.370399
# 407       689    3.369288  3.370399
# 408       689    3.397255  3.370399
#
# [409 rows x 3 columns]

# %%
wt_pos_cgreGFP = result_wt_cgreGFP.Position.unique()
print(len(wt_pos_cgreGFP))
# Out:
# 234

# %%
wt_median_cgreGFP = {}
for pos in wt_pos_cgreGFP:
    wt_median_cgre = result_wt_cgreGFP[result_wt_cgreGFP.Position == pos]
    wt_median_cgreGFP[pos] = wt_median_cgre['Brightness'].median()

# %%
wt_median_cgreGFP = pd.DataFrame.from_dict(wt_median_cgreGFP, orient='index')
wt_median_cgreGFP.columns =['Median']
wt_median_cgreGFP = wt_median_cgreGFP.rename_axis('Position').reset_index()
result_wt_median_cgreGFP = result_wt_cgreGFP.merge(wt_median_cgreGFP, how='outer')
result_wt_median_cgreGFP.columns =['Position', 'Brightness','Median']

result_wt_median_cgreGFP
# Out:
#      Position  Brightness    Median
# 0          17    3.287761  3.287761
# 1         194    3.284994  3.290743
# 2         194    3.296491  3.290743
# 3         227    3.280850  3.280850
# 4         266    3.280228  3.280228
# ..        ...         ...       ...
# 382       677    3.289866  3.290431
# 383       677    3.290996  3.290431
# 384       690    3.288076  3.288076
# 385        95    3.293775  3.281149
# 386        95    3.268523  3.281149
#
# [387 rows x 3 columns]

# %%
wt_pos_ppluGFP = result_wt_ppluGFP.Position.unique()
print(len(wt_pos_ppluGFP))
# Out:
# 223

# %%
wt_median_ppluGFP = {}
for pos in wt_pos_ppluGFP:
    wt_median_pplu = result_wt_ppluGFP[result_wt_ppluGFP.Position == pos]
    wt_median_ppluGFP[pos] = wt_median_pplu['Brightness'].median()

# %%
wt_median_ppluGFP = pd.DataFrame.from_dict(wt_median_ppluGFP, orient='index')
wt_median_ppluGFP.columns =['Median']
wt_median_ppluGFP = wt_median_ppluGFP.rename_axis('Position').reset_index()
result_wt_median_ppluGFP = result_wt_ppluGFP.merge(wt_median_ppluGFP, how='outer')
result_wt_median_ppluGFP.columns =['Position', 'Brightness','Median']

result_wt_median_ppluGFP
# Out:
#      Position  Brightness    Median
# 0         125    3.312812  3.312812
# 1         131    3.299768  3.299768
# 2         131    3.310262  3.299768
# 3         131    3.286953  3.299768
# 4          14    3.301749  3.301749
# ..        ...         ...       ...
# 426       656    3.313451  3.307961
# 427       656    3.302471  3.307961
# 428       659    3.310481  3.309460
# 429       659    3.309460  3.309460
# 430       659    3.307731  3.309460
#
# [431 rows x 3 columns]

# %%
median_wt_amacGFP = result_wt_median_amacGFP["Median"]
mut_wt_amacGFP = result_wt_median_amacGFP["Brightness"]
corrP_wt_amacGFP = median_wt_amacGFP.corr(mut_wt_amacGFP, method='pearson')
corrS_wt_amacGFP = median_wt_amacGFP.corr(mut_wt_amacGFP, method='spearman')
var_wt_amacGFP = median_wt_amacGFP.var()

median_wt_cgreGFP = result_wt_median_cgreGFP["Median"]
mut_wt_cgreGFP = result_wt_median_cgreGFP["Brightness"]
corrP_wt_cgreGFP = median_wt_cgreGFP.corr(mut_wt_cgreGFP, method='pearson')
corrS_wt_cgreGFP = median_wt_cgreGFP.corr(mut_wt_cgreGFP, method='spearman')
var_wt_cgreGFP = median_wt_cgreGFP.var()

median_wt_ppluGFP = result_wt_median_ppluGFP["Median"]
mut_wt_ppluGFP = result_wt_median_ppluGFP["Brightness"]
corrP_wt_ppluGFP = median_wt_ppluGFP.corr(mut_wt_ppluGFP, method='pearson')
corrS_wt_ppluGFP = median_wt_ppluGFP.corr(mut_wt_ppluGFP, method='spearman')
var_wt_ppluGFP = median_wt_ppluGFP.var()

# %%
figure, axes = plt.subplots(3,1, figsize=(20,30))

result_wt_median_amacGFP.plot(kind='scatter', x='Median', y='Brightness', color='deepskyblue', label='CC: P={} S={}  VAR={}'.format(corrP_wt_amacGFP,corrS_wt_amacGFP, var_wt_amacGFP), s=10, alpha=0.5, ax=axes[0])
axes[0].set_title('amacGFP')


result_wt_median_cgreGFP.plot(kind='scatter', x='Median', y='Brightness', color='deeppink', label='CC: P={} S={}  VAR={}'.format(corrP_wt_cgreGFP,corrS_wt_cgreGFP, var_wt_cgreGFP),s=10, alpha=0.5, ax=axes[1])
axes[1].set_title('cgreGFP')


result_wt_median_ppluGFP.plot(kind='scatter', x='Median', y='Brightness', color='blueviolet', label='CC: P={} S={}  VAR={}'.format(corrP_wt_ppluGFP,corrS_wt_ppluGFP, var_wt_ppluGFP),s=10, alpha=0.5, ax=axes[2])
axes[2].set_title('ppluGFP')

for ax in axes.flat:
    ax.set(xlabel='Median brightness nucleotide position', ylabel='Brightness nucleotide position')

plt.savefig('Syn_mut_wt_median.png', dpi=300)

# %% [markdown]
# ### **<font color=orange>Boxplot (normalized)</font>**

# %%
position_wt_amacGFP = {}
brightness_wt_amacGFP = {}

for index, row in wt_bright_amacGFP.iterrows(): 
        if ':' not in row["nt_genotype"]:
            try:
                position_wt_amacGFP[index] = int(row["nt_genotype"][1:-1])
                brightness_wt_amacGFP[index] = row["replicates_mean_brightness"]/1.1793308925118149
            except IndexError:
                pass
            except ValueError:
                pass

# %%
pos_wt_amacGFP = pd.DataFrame.from_dict(position_wt_amacGFP, orient='index')
bri_wt_amacGFP = pd.DataFrame.from_dict(brightness_wt_amacGFP, orient='index')
result_wt_amacGFP = pd.concat([pos_wt_amacGFP, bri_wt_amacGFP], axis=1, sort=False)
#result_amacGFP = result_amacGFP.dropna()
result_wt_amacGFP.columns =['Position', 'Brightness']
result_wt_amacGFP

# %%
position_wt_cgreGFP = {}
brightness_wt_cgreGFP = {}

for index, row in wt_bright_cgreGFP.iterrows(): 
        if ':' not in row["nt_genotype"]:
            try:
                position_wt_cgreGFP[index] = int(row["nt_genotype"][1:-1])
                brightness_wt_cgreGFP[index] = row["replicates_mean_brightness"]/1.3706405019099068
            except IndexError:
                pass
            except ValueError:
                pass

# %%
pos_wt_cgreGFP = pd.DataFrame.from_dict(position_wt_cgreGFP, orient='index')
bri_wt_cgreGFP = pd.DataFrame.from_dict(brightness_wt_cgreGFP, orient='index')
result_wt_cgreGFP = pd.concat([pos_wt_cgreGFP, bri_wt_cgreGFP], axis=1, sort=False)
#result_cgreGFP = result_cgreGFP.dropna()
result_wt_cgreGFP.columns =['Position', 'Brightness']
result_wt_cgreGFP

# %%
position_wt_ppluGFP = {}
brightness_wt_ppluGFP = {}

for index, row in wt_bright_ppluGFP.iterrows(): 
        if ':' not in row["nt_genotype"]:
            try:
                position_wt_ppluGFP[index] = int(row["nt_genotype"][1:-1])
                brightness_wt_ppluGFP[index] = row["replicates_mean_brightness"]/1.2775111106220145
            except IndexError:
                pass
            except ValueError:
                pass

# %%
pos_wt_ppluGFP = pd.DataFrame.from_dict(position_wt_ppluGFP, orient='index')
bri_wt_ppluGFP = pd.DataFrame.from_dict(brightness_wt_ppluGFP, orient='index')
result_wt_ppluGFP = pd.concat([pos_wt_ppluGFP, bri_wt_ppluGFP], axis=1, sort=False)
#result_cgreGFP = result_cgreGFP.dropna()
result_wt_ppluGFP.columns =['Position', 'Brightness']
result_wt_ppluGFP

# %%
import seaborn as sns

plt.figure(figsize=(50,50))
for gene, dataset, i, color in [('amacGFP', result_wt_amacGFP, 1, 'lawngreen'),('cgreGFP', result_wt_cgreGFP, 2, 'limegreen'),('ppluGFP', result_wt_ppluGFP, 3, 'green')]:
    plt.subplot(3,1,i)
    ax=sns.boxplot(x='Position', y='Brightness', data=dataset)#, hue=color), 
                #palette=['grey','orange', 'red', 'purple','royalblue','green'])
    ax.set_xlabel('Nucleotide position in the genome')
    ax.set_ylabel('Mean brightness')
    #ax.set_xticks(np.arange(0, 250, 5))
    plt.ylim(0.7,0.9)
    plt.title(gene, size=30)

plt.tight_layout()
plt.savefig('Syn_mut_wt_norm_box.png', dpi=300)

# %% [markdown]
# ### **<font color=orange>Box plot (scaled)</font>**

# %%
result_wt_amacGFP['gene'] = 'amacGFP'
result_wt_cgreGFP['gene'] = 'cgreGFP'
result_wt_ppluGFP['gene'] = 'ppluGFP'

# %%
result_wt_global = pd.concat([result_wt_amacGFP, result_wt_cgreGFP, result_wt_ppluGFP], sort=False)
result_wt_global

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

result_wt_global[['Brightness']] = scaler.fit_transform(result_wt_global[['Brightness']])

result_wt_global

# %%
result_wt_global_amacGFP = result_wt_global[result_wt_global.gene=='amacGFP']
result_wt_global_amacGFP.reset_index(inplace=True)

result_wt_global_cgreGFP = result_wt_global[result_wt_global.gene=='cgreGFP']
result_wt_global_cgreGFP.reset_index(inplace=True)

result_wt_global_ppluGFP = result_wt_global[result_wt_global.gene=='ppluGFP']
result_wt_global_ppluGFP.reset_index(inplace=True)

# %%
plt.figure(figsize=(50,50))
for gene, dataset, i, color in [('amacGFP', result_wt_global_amacGFP, 1, 'lawngreen'),('cgreGFP', result_wt_global_cgreGFP, 2, 'limegreen'),('ppluGFP', result_wt_global_ppluGFP, 3, 'green')]:
    plt.subplot(3,1,i)
    ax=sns.boxplot(x='Position', y='Brightness', data=dataset)#, hue=color), 
                #palette=['grey','orange', 'red', 'purple','royalblue','green'])
    ax.set_xlabel('Nucleotide position in the genome')
    ax.set_ylabel('Mean brightness')
    #ax.set_xticks(np.arange(0, 250, 5))
    plt.ylim(0,1.2)
    plt.title(gene, size=30)

plt.tight_layout()
plt.savefig('Syn_mut_wt_scaled_box.png', dpi=300)

# %% [markdown]
# ### **<font color=orange>Scatter plot (normalized)</font>**

# %%
wt_pos_amacGFP = result_wt_amacGFP.Position.unique()
print(len(wt_pos_amacGFP))
# Out:
# 242

# %%
wt_median_amacGFP = {}
for pos in wt_pos_amacGFP:
    wt_median_amac = result_wt_amacGFP[result_wt_amacGFP.Position == pos]
    wt_median_amacGFP[pos] = wt_median_amac['Brightness'].median()

# %%
wt_median_amacGFP = pd.DataFrame.from_dict(wt_median_amacGFP, orient='index')
wt_median_amacGFP.columns =['Median']
wt_median_amacGFP = wt_median_amacGFP.rename_axis('Position').reset_index()
result_wt_median_amacGFP = result_wt_amacGFP.merge(wt_median_amacGFP, how='outer')
result_wt_median_amacGFP.columns =['Position', 'Brightness','Gene','Median']

result_wt_median_amacGFP
# Out:
#      Position  Brightness     Gene    Median
# 0         227    3.377457  amacGFP  3.377457
# 1         269    3.373734  amacGFP  3.373734
# 2         353    3.391209  amacGFP  3.382591
# 3         353    3.377940  amacGFP  3.382591
# 4         353    3.382591  amacGFP  3.382591
# ..        ...         ...      ...       ...
# 404       680    3.363385  amacGFP  3.363385
# 405       686    3.359819  amacGFP  3.359819
# 406       689    3.370399  amacGFP  3.370399
# 407       689    3.369288  amacGFP  3.370399
# 408       689    3.397255  amacGFP  3.370399
#
# [409 rows x 4 columns]

# %%
wt_pos_cgreGFP = result_wt_cgreGFP.Position.unique()
print(len(wt_pos_cgreGFP))
# Out:
# 234

# %%
wt_median_cgreGFP = {}
for pos in wt_pos_cgreGFP:
    wt_median_cgre = result_wt_cgreGFP[result_wt_cgreGFP.Position == pos]
    wt_median_cgreGFP[pos] = wt_median_cgre['Brightness'].median()

# %%
wt_median_cgreGFP = pd.DataFrame.from_dict(wt_median_cgreGFP, orient='index')
wt_median_cgreGFP.columns =['Median']
wt_median_cgreGFP = wt_median_cgreGFP.rename_axis('Position').reset_index()
result_wt_median_cgreGFP = result_wt_cgreGFP.merge(wt_median_cgreGFP, how='outer')
result_wt_median_cgreGFP.columns =['Position', 'Brightness','Gene','Median']

result_wt_median_cgreGFP
# Out:
#      Position  Brightness     Gene    Median
# 0          17    3.287761  cgreGFP  3.287761
# 1         194    3.284994  cgreGFP  3.290743
# 2         194    3.296491  cgreGFP  3.290743
# 3         227    3.280850  cgreGFP  3.280850
# 4         266    3.280228  cgreGFP  3.280228
# ..        ...         ...      ...       ...
# 382       677    3.289866  cgreGFP  3.290431
# 383       677    3.290996  cgreGFP  3.290431
# 384       690    3.288076  cgreGFP  3.288076
# 385        95    3.293775  cgreGFP  3.281149
# 386        95    3.268523  cgreGFP  3.281149
#
# [387 rows x 4 columns]

# %%
wt_pos_ppluGFP = result_wt_ppluGFP.Position.unique()
print(len(wt_pos_ppluGFP))
# Out:
# 223

# %%
wt_median_ppluGFP = {}
for pos in wt_pos_ppluGFP:
    wt_median_pplu = result_wt_ppluGFP[result_wt_ppluGFP.Position == pos]
    wt_median_ppluGFP[pos] = wt_median_pplu['Brightness'].median()

# %%
wt_median_ppluGFP = pd.DataFrame.from_dict(wt_median_ppluGFP, orient='index')
wt_median_ppluGFP.columns =['Median']
wt_median_ppluGFP = wt_median_ppluGFP.rename_axis('Position').reset_index()
result_wt_median_ppluGFP = result_wt_ppluGFP.merge(wt_median_ppluGFP, how='outer')
result_wt_median_ppluGFP.columns =['Position', 'Brightness','Gene','Median']

result_wt_median_ppluGFP
# Out:
#      Position  Brightness     Gene    Median
# 0         125    3.312812  ppluGFP  3.312812
# 1         131    3.299768  ppluGFP  3.299768
# 2         131    3.310262  ppluGFP  3.299768
# 3         131    3.286953  ppluGFP  3.299768
# 4          14    3.301749  ppluGFP  3.301749
# ..        ...         ...      ...       ...
# 426       656    3.313451  ppluGFP  3.307961
# 427       656    3.302471  ppluGFP  3.307961
# 428       659    3.310481  ppluGFP  3.309460
# 429       659    3.309460  ppluGFP  3.309460
# 430       659    3.307731  ppluGFP  3.309460
#
# [431 rows x 4 columns]

# %%
median_wt_amacGFP = result_wt_median_amacGFP["Median"]
mut_wt_amacGFP = result_wt_median_amacGFP["Brightness"]
corrP_wt_amacGFP = median_wt_amacGFP.corr(mut_wt_amacGFP, method='pearson')
corrS_wt_amacGFP = median_wt_amacGFP.corr(mut_wt_amacGFP, method='spearman')
var_wt_amacGFP = median_wt_amacGFP.var()

median_wt_cgreGFP = result_wt_median_cgreGFP["Median"]
mut_wt_cgreGFP = result_wt_median_cgreGFP["Brightness"]
corrP_wt_cgreGFP = median_wt_cgreGFP.corr(mut_wt_cgreGFP, method='pearson')
corrS_wt_cgreGFP = median_wt_cgreGFP.corr(mut_wt_cgreGFP, method='spearman')
var_wt_cgreGFP = median_wt_cgreGFP.var()

median_wt_ppluGFP = result_wt_median_ppluGFP["Median"]
mut_wt_ppluGFP = result_wt_median_ppluGFP["Brightness"]
corrP_wt_ppluGFP = median_wt_ppluGFP.corr(mut_wt_ppluGFP, method='pearson')
corrS_wt_ppluGFP = median_wt_ppluGFP.corr(mut_wt_ppluGFP, method='spearman')
var_wt_ppluGFP = median_wt_ppluGFP.var()

# %%
figure, axes = plt.subplots(3,1, figsize=(20,30))

result_wt_median_amacGFP.plot(kind='scatter', x='Median', y='Brightness', color='deepskyblue', label='CC: P={} S={}  VAR={}'.format(corrP_wt_amacGFP,corrS_wt_amacGFP, var_wt_amacGFP), s=10, alpha=0.5, ax=axes[0])
axes[0].set_title('amacGFP')
axes[0].set_xticks(np.arange(3.25, 3.45, step=0.05));
axes[0].set_xlim(xmin=3.24,xmax=3.46)
axes[0].set_yticks(np.arange(3.25, 3.55, step=0.05));
axes[0].set_ylim(ymin=3.24,ymax=3.51)
axes[0].grid(alpha=0.5)


result_wt_median_cgreGFP.plot(kind='scatter', x='Median', y='Brightness', color='deeppink', label='CC: P={} S={}  VAR={}'.format(corrP_wt_cgreGFP,corrS_wt_cgreGFP, var_wt_cgreGFP),s=10, alpha=0.5, ax=axes[1])
axes[1].set_title('cgreGFP')
axes[1].set_xticks(np.arange(3.25, 3.45, step=0.05));
axes[1].set_xlim(xmin=3.24,xmax=3.46)
axes[1].set_yticks(np.arange(3.25, 3.55, step=0.05));
axes[1].set_ylim(ymin=3.24,ymax=3.51)
axes[1].grid(alpha=0.5)

result_wt_median_ppluGFP.plot(kind='scatter', x='Median', y='Brightness', color='blueviolet', label='CC: P={} S={}  VAR={}'.format(corrP_wt_ppluGFP,corrS_wt_ppluGFP, var_wt_ppluGFP),s=10, alpha=0.5, ax=axes[2])
axes[2].set_title('ppluGFP')
axes[2].set_xticks(np.arange(3.25, 3.45, step=0.05));
axes[2].set_xlim(xmin=3.24,xmax=3.46)
axes[2].set_yticks(np.arange(3.25, 3.55, step=0.05));
axes[2].set_ylim(ymin=3.24,ymax=3.51)
axes[2].grid(alpha=0.5)

for ax in axes.flat:
    ax.set(xlabel='Median brightness nucleotide position', ylabel='Brightness nucleotide position')

plt.savefig('Syn_mut_wt_median_norm.png', dpi=300)

# %%
#wt_bright_amacGFP['replicates_mean_brightness'] = wt_bright_amacGFP['replicates_mean_brightness']/1.1793308925118149
amacGFP_var = wt_bright_amacGFP['replicates_mean_brightness'].var()
amacGFP_mean = wt_bright_amacGFP['replicates_mean_brightness'].mean()

#wt_bright_cgreGFP['replicates_mean_brightness'] = wt_bright_cgreGFP['replicates_mean_brightness']/1.3706405019099068
cgreGFP_var = wt_bright_cgreGFP['replicates_mean_brightness'].var()
cgreGFP_mean = wt_bright_cgreGFP['replicates_mean_brightness'].mean()

#wt_bright_ppluGFP['replicates_mean_brightness'] = wt_bright_ppluGFP['replicates_mean_brightness']/1.2775111106220145
ppluGFP_var = wt_bright_ppluGFP['replicates_mean_brightness'].var()
ppluGFP_mean = wt_bright_ppluGFP['replicates_mean_brightness'].mean()

# %%
amacGFP_disp = (amacGFP_var*amacGFP_var)/amacGFP_mean
cgreGFP_disp = (cgreGFP_var*cgreGFP_var)/cgreGFP_mean
ppluGFP_disp = (ppluGFP_var*ppluGFP_var)/ppluGFP_mean

print(amacGFP_disp, cgreGFP_disp, ppluGFP_disp)
# Out:
# 1.5038267195648324e-07 5.949339896325244e-08 6.453532458148546e-08

# %%
wt_bright_amacGFP['replicates_mean_brightness'].describe()
# Out:
# count    1089.000000
# mean        3.370149
# std         0.026682
# min         3.253286
# 25%         3.356222
# 50%         3.370697
# 75%         3.384818
# max         3.491704
# Name: replicates_mean_brightness, dtype: float64

# %%
wt_bright_cgreGFP['replicates_mean_brightness'].describe()
# Out:
# count    1588.000000
# mean        3.281845
# std         0.021021
# min         3.092580
# 25%         3.270866
# 50%         3.283118
# 75%         3.294387
# max         3.368563
# Name: replicates_mean_brightness, dtype: float64

# %%
wt_bright_ppluGFP['replicates_mean_brightness'].describe()
# Out:
# count    2765.000000
# mean        3.308342
# std         0.021496
# min         3.169941
# 25%         3.296819
# 50%         3.309222
# 75%         3.320814
# max         3.422010
# Name: replicates_mean_brightness, dtype: float64

# %%
wt_mut_ppluGFP
# Out:
#       level_0   index     gene aa_genotype_pseudo              nt_genotype  \
# 0       44396  123801  ppluGFP                 wt                    A125G
# 1       44397  123802  ppluGFP                 wt              A125G:A251T
# 2       44398  123803  ppluGFP                 wt              A125G:A296G
# 3       44399  123804  ppluGFP                 wt              A125G:A296T
# 4       44400  123805  ppluGFP                 wt  A125G:A299G:G320T:A614G
# ...       ...     ...      ...                ...                      ...
# 2760    47156  126561  ppluGFP                 wt                    T659A
# 2761    47157  126562  ppluGFP                 wt              T659A:C662T
# 2762    47158  126563  ppluGFP                 wt                    T659C
# 2763    47159  126564  ppluGFP                 wt                    T659G
# 2764    47160  126565  ppluGFP                 wt                       wt
#
#       total_cell_count  n_replicates  replicates_stdev_weighted  \
# ...

# %%
#wt_bright_amacGFP['replicates_mean_brightness'] = wt_bright_amacGFP['replicates_mean_brightness']/1.1793308925118149
amacGFP_var = wt_mut_amacGFP['replicates_mean_brightness'].var()
amacGFP_mean = wt_mut_amacGFP['replicates_mean_brightness'].mean()

#wt_bright_cgreGFP['replicates_mean_brightness'] = wt_bright_cgreGFP['replicates_mean_brightness']/1.3706405019099068
cgreGFP_var = wt_mut_cgreGFP['replicates_mean_brightness'].var()
cgreGFP_mean = wt_mut_cgreGFP['replicates_mean_brightness'].mean()

#wt_bright_ppluGFP['replicates_mean_brightness'] = wt_bright_ppluGFP['replicates_mean_brightness']/1.2775111106220145
ppluGFP_var = wt_mut_ppluGFP['replicates_mean_brightness'].var()
ppluGFP_mean = wt_mut_ppluGFP['replicates_mean_brightness'].mean()

print(amacGFP_var, cgreGFP_var, ppluGFP_var)
# Out:
# 0.0009901358339470636 0.0008301194243207825 0.000754107555128891

# %%
amacGFP_disp = (amacGFP_var*amacGFP_var)/amacGFP_mean
cgreGFP_disp = (cgreGFP_var*cgreGFP_var)/cgreGFP_mean
ppluGFP_disp = (ppluGFP_var*ppluGFP_var)/ppluGFP_mean

print(amacGFP_disp, cgreGFP_disp, ppluGFP_disp)
# Out:
# 2.466634616262498e-07 1.5319319163438548e-07 1.3455243339877597e-07

# %%
wt_mut_amacGFP['replicates_mean_brightness'].describe()
# Out:
# count    1089.000000
# mean        3.974520
# std         0.031466
# min         3.836700
# 25%         3.958096
# 50%         3.975167
# 75%         3.991821
# max         4.117875
# Name: replicates_mean_brightness, dtype: float64

# %%
wt_mut_cgreGFP['replicates_mean_brightness'].describe()
# Out:
# count    1588.000000
# mean        4.498230
# std         0.028812
# min         4.238816
# 25%         4.483181
# 50%         4.499974
# 75%         4.515420
# max         4.617089
# Name: replicates_mean_brightness, dtype: float64

# %%
wt_mut_ppluGFP['replicates_mean_brightness'].describe()
# Out:
# count    2765.000000
# mean        4.226443
# std         0.027461
# min         4.049635
# 25%         4.211723
# 50%         4.227568
# 75%         4.242377
# max         4.371656
# Name: replicates_mean_brightness, dtype: float64
