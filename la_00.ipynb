# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt

# %%
dataset = 'amac_cgre_pplu_nt_genotype_indexed_clean.txt'

# %%
# %run "init_functions.py"

# %%
data_folder
# Out:
# 'C:\\Users\\Elisenda\\GFP_global_landscape\\data\\'

# %%
by_nt = pd.read_table(os.path.join(data_folder, '_global_GFP', dataset))

# %%
by_nt
# Out:
#                                               nt_genotype     gene  \
# 0                                                   A100C  amacGFP
# 1                           A100C:A201T:G243A:T457A:A489G  amacGFP
# 2                     A100C:A304C:A436C:T452C:T532C:C566T  amacGFP
# 3                                 A100C:A489T:T667C:G681T  amacGFP
# 4                                       A100C:C110G:A598G  amacGFP
# ...                                                   ...      ...
# 118704           T95G:C134T:C170T:C302T:T426C:T621C:A650G  cgreGFP
# 118705  T95G:T116C:C155T:T192C:G403A:C463A:A550G:A628T...  cgreGFP
# 118706                                                 wt  amacGFP
# 118707                                                 wt  cgreGFP
# 118708                                                 wt  ppluGFP
#
#                              aa_genotype_pseudo  total_cell_count  \
# 0                                          E36A            162.69
# ...

# %%
by_aa_upd = pd.read_table(r'C:\Users\Elisenda\GFP_global_landscape\analysis\lis\amac_cgre_pplu_aa_genotype_indexed_clean_CDF_april2020.txt')
by_aa_upd
# Out:
#        Unnamed: 0 aa_genotype_pseudo     gene  total_cell_count  n_replicates  \
# 0               3              *246G  amacGFP           1986.35           8.0
# 1               6              *246L  amacGFP             32.68           1.0
# 2               9              *246R  amacGFP            312.67           4.0
# 3              11              *246W  amacGFP            331.73           1.0
# 4             332              A160D  amacGFP            684.24           4.0
# ...           ...                ...      ...               ...           ...
# 92383       92379         Y95S:N222Y  ppluGFP             96.47           1.0
# 92384       92380    Y95S:R99C:F113S  ppluGFP             65.83           1.0
# 92385       92381         Y95S:S192G  ppluGFP             55.05           1.0
# 92386       92383         Y95S:Y103C  ppluGFP             88.40           1.0
# 92387       92387                 wt  ppluGFP        3198404.78        2765.0
#
# ...

# %%
by_nt_upd = pd.read_table(r'C:\Users\Elisenda\GFP_global_landscape\analysis\lis\amac_cgre_pplu_nt_genotype_indexed_clean_CDF_april2020.txt')
by_nt_upd
# Out:
#         Unnamed: 0                                      nt_genotype     gene  \
# 0                0                                            A100C  amacGFP
# 1                1                                A100C:A144T:C172A  amacGFP
# 2                2              A100C:A304C:A436C:T452C:T532C:C566T  amacGFP
# 3                3                                      A100C:A349T  amacGFP
# 4                4                          A100C:A489T:T667C:G681T  amacGFP
# ...            ...                                              ...      ...
# 126561      125673  T661C:C662G:G663C:C664A:A665T:T666G:G667A:A668T  ppluGFP
# 126562      125679                                T666A:G667T:A668G  ppluGFP
# 126563      125682                                            T666C  ppluGFP
# 126564      125686                                            T666G  ppluGFP
# 126565      126565                                               wt  ppluGFP
#
# ...
